# %%
import gc
import numpy as np
import pandas as pd
import lightgbm as lgb
from time import time
from datetime import date, timedelta
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## 1 预处理

# %%
# train_data_path = "../data/train.csv"
# df_train = pd.read_csv(
#     train_data_path, usecols=[1, 2, 3, 4, 5], dtype={'onpromotion': bool}, 
#     converters={'unit_sales': lambda x: np.log1p(float(x)) if float(x) > 0 else 0}, 
#     parse_dates=['date'], skiprows=range(1, 66458909)
# )
# df_2017 = df_train[df_train['date'] >= '2017-01-01']

df_2017 = pd.read_csv("../data/train-2017.csv", parse_dates=['date'])

df_test = pd.read_csv(
    "../data/test.csv", # usecols=[0, 1, 2, 3, 4], 
    dtype={'onpromotion': bool}, parse_dates=['date']
).set_index(['store_nbr', 'item_nbr', 'date'])

items = pd.read_csv("../data/items.csv").set_index('item_nbr')

stores = pd.read_csv("../data/stores.csv").set_index("store_nbr")

# %%
encoder = LabelEncoder()

items['family'] = encoder.fit_transform(items['family'].values)

stores['city'] = encoder.fit_transform(stores['city'].values)
stores['state'] = encoder.fit_transform(stores['state'].values)
stores['type'] = encoder.fit_transform(stores['type'].values)

# %% [markdown]
# 每个店铺每件商品每天的促销情况

# %%
promo_2017_train = df_2017.set_index(
    ['store_nbr', 'item_nbr', 'date'])[['onpromotion']].unstack(
        level=-1).fillna(False)
promo_2017_train.columns = promo_2017_train.columns.get_level_values(1)

promo_2017_test = df_test[['onpromotion']].unstack(level=-1).fillna(False)
promo_2017_test.columns = promo_2017_test.columns.get_level_values(1)
promo_2017_test = promo_2017_test.reindex(promo_2017_train.index).fillna(False)

promo_2017 = pd.concat([promo_2017_train, promo_2017_test], axis=1)

del promo_2017_train, promo_2017_test
gc.collect()
# Out:
# 14

# %% [markdown]
# 每个店铺每件商品每天的销量

# %%
df_2017 = df_2017.set_index(
    ['store_nbr', 'item_nbr', 'date'])[['unit_sales']].unstack(
        level=-1).fillna(0)
df_2017.columns = df_2017.columns.get_level_values(1)

# %%
items = items.reindex(df_2017.index.get_level_values(1))
stores = stores.reindex(df_2017.index.get_level_values(0))

# %% [markdown]
# 每件商品每天的销量

# %%
df_2017_item = df_2017.groupby('item_nbr')[df_2017.columns].sum()

# %% [markdown]
# 每件商品每天的促销情况

# %%
promo_2017_item = promo_2017.groupby('item_nbr')[promo_2017.columns].sum()

# %% [markdown]
# 每个种类的商品在每个店铺每天的销量

# %%
df_2017_store_class = df_2017.reset_index()
df_2017_store_class['class'] = items['class'].values
df_2017_store_class_index = df_2017_store_class[['class', 'store_nbr']]
df_2017_store_class = df_2017_store_class.groupby(['class', 'store_nbr'])[df_2017.columns].sum()

# %% [markdown]
# 每个种类的商品在每个店铺每天的促销情况

# %%
promo_2017_store_class = promo_2017.reset_index()
promo_2017_store_class['class'] = items['class'].values
promo_2017_store_class_index = promo_2017_store_class[['class', 'store_nbr']]
promo_2017_store_class = promo_2017_store_class.groupby(['class', 'store_nbr'])[promo_2017.columns].sum()

# %% [markdown]
# ## 2 特征工程（准备数据集）

# %%
def get_timespan(df, dt, minus, periods, freq='D'):
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

# %%
def prepare_dataset(df, promo_df, t2017, is_train=True, name_prefix=None):
    # 促销天数特征（6个特征）
    X = {
        'promo_14_2017': get_timespan(promo_df, t2017, 14, 14).sum(axis=1).values,  # 前14天中每个店铺商品的促销天数
        'promo_60_2017': get_timespan(promo_df, t2017, 60, 60).sum(axis=1).values,  # 前60天中每个店铺商品的促销天数
        'promo_140_2017': get_timespan(promo_df, t2017, 140, 140).sum(axis=1).values,  # 前140天中每个店铺商品的促销天数
        'promo_3_2017_aft': get_timespan(promo_df, t2017 + timedelta(days=16), 15, 3).sum(axis=1).values,  # 后3天中每个店铺商品的促销天数
        'promo_7_2017_aft': get_timespan(promo_df, t2017 + timedelta(days=16), 15, 7).sum(axis=1).values,  # 后7天中每个店铺商品的促销天数
        'promo_14_2017_aft': get_timespan(promo_df, t2017 + timedelta(days=16), 15, 14).sum(axis=1).values  # 后14天中每个店铺商品的促销天数
    }
    
    # 促销销量和正常销量特征（24个特征）
    for i in [3, 7, 14, 30, 60, 140]:
        tmp1 = get_timespan(df, t2017, i, i)  # 前i天每个店铺商品的销量
        tmp2 = (get_timespan(promo_df, t2017, i, i) > 0) * 1  # 前i天每个店铺商品的促销情况（是否促销）
        
        X['has_promo_mean_%s' % i] = (tmp1 * tmp2.replace(0, np.nan)).mean(axis=1).values  # 前i天每个店铺商品平均促销销量
        X['has_promo_mean_%s_decay' % i] = (tmp1 * tmp2.replace(0, np.nan) * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values  # 前i天每个店铺商品促销销量和（带衰减）
        
        X['no_promo_mean_%s' % i] = (tmp1 * (1 - tmp2).replace(0, np.nan)).mean(axis=1).values  # 前i天每个店铺商品平均正常销量
        X['no_promo_mean_%s_decay' % i] = (tmp1 * (1 - tmp2).replace(0, np.nan) * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values  # 前i天每个店铺商品正常销量和（带衰减）
        
    # 销量统计特征（42个特征）
    for i in [3, 7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017, i, i)  # 前i天每个店铺商品的销量
        X['diff_%s_mean' % i] = tmp.diff(axis=1).mean(axis=1).values  # 前i天每个店铺商品销量的平均一阶差分
        X['mean_%s_decay' % i] = (tmp * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values  # 前i天每个店铺商品销量的和（带衰减）
        X['mean_%s' % i] = tmp.mean(axis=1).values  # 前i天每个店铺商品销量的均值
        X['median_%s' % i] = tmp.median(axis=1).values  # 前i天每个店铺商品销量的中位数
        X['min_%s' % i] = tmp.min(axis=1).values  # 前i天每个店铺商品销量的最小值
        X['max_%s' % i] = tmp.max(axis=1).values  # 前i天每个店铺商品销量的最大值
        X['std_%s' % i] = tmp.std(axis=1).values  # 前i天每个店铺商品销量的标准差
    
    # 销量统计特征2（42个特征）
    for i in [3, 7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017 + timedelta(days=-7), i, i)  # 7天前的前i天每个店铺商品的销量
        X['diff_%s_mean_2' % i] = tmp.diff(axis=1).mean(axis=1).values  # 7天前的前i天每个店铺商品销量的平均一阶差分
        X['mean_%s_decay_2' % i] = (tmp * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values  # 7天前的前i天每个店铺商品销量的和（带衰减）
        X['mean_%s_2' % i] = tmp.mean(axis=1).values  # 7天前的前i天每个店铺商品销量的平均值
        X['median_%s_2' % i] = tmp.median(axis=1).values  # 7天前的前i天每个店铺商品销量的中位数
        X['min_%s_2' % i] = tmp.min(axis=1).values  # 7天前的前i天每个店铺商品销量的最小值
        X['max_%s_2' % i] = tmp.max(axis=1).values  # 7天前的前i天每个店铺商品销量的最大值
        X['std_%s_2' % i] = tmp.std(axis=1).values  # 7天前的前i天每个店铺商品销量的标准差
        
    # 有销量和有促销的天数特征（30个特征）
    for i in [7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017, i, i)  # 前i天每个店铺商品的销量
        X['has_sales_days_in_last_%s' % i] = (tmp > 0).sum(axis=1).values  # 前i天每个店铺商品有销量的天数
        X['last_has_sales_day_in_last_%s' % i] = i - ((tmp > 0) * np.arange(i)).max(axis=1).values  # 前i天每个店铺商品距离上一次有销量的天数
        X['first_has_sales_day_in_last_%s' % i] = ((tmp > 0) * np.arange(i, 0, -1)).max(axis=1).values  # 前i天每个店铺商品距离第一次有销量的天数
        
        tmp = get_timespan(promo_df, t2017, i, i)  # 前i天每个店铺商品的促销情况
        X['has_promo_days_in_last_%s' % i] = (tmp > 0).sum(axis=1).values  # 前i天每个店铺商品有促销的天数
        X['last_has_promo_day_in_last_%s' % i] = i - ((tmp > 0) * np.arange(i)).max(axis=1).values  # 前i天每个店铺商品距离上一次有促销的天数
        X['first_has_promo_day_in_last_%s' % i] = ((tmp > 0) * np.arange(i, 0, -1)).max(axis=1).values  # 前i天每个店铺商品距离第一次有促销的天数
        
    # 后15天的促销情况特征（3个特征）
    tmp = get_timespan(promo_df, t2017 + timedelta(days=16), 15, 15)  # 后15天每个店铺商品的促销情况
    X['has_promo_days_in_after_15_days'] = (tmp > 0).sum(axis=1).values  # 后15天每个店铺商品有促销的天数
    X['last_has_promo_day_in_after_15_days'] = ((tmp > 0) * np.arange(1, 16)).max(axis=1).values  # 后15天每个店铺商品距离最后一次有促销的天数
    X['first_has_promo_day_in_after_15_days'] = 16 - ((tmp > 0) * np.arange(15, 0, -1)).max(axis=1).values  # 后15天每个店铺商品距离最近一次有促销的天数
    
    # 前15天的销量（15个特征）
    for i in range(1, 16):
        X['day_%s_2017' % i] = get_timespan(df, t2017, i, 1).values.ravel()
    
    # 前4（20）周每天的平均销量（14个特征）
    for i in range(7):
        X['mean_4_dow{}_2017'.format(i)] = get_timespan(df, t2017, 28-i, 4, freq='7D').mean(axis=1).values
        X['mean_20_dow{}_2017'.format(i)] = get_timespan(df, t2017, 140-i, 20, freq='7D').mean(axis=1).values
        
    # 前16天到后15天每天的促销情况（32个特征）
    for i in range(-16, 16):
        X['promo_{}'.format(i)] = promo_df[t2017 + timedelta(days=i)].values.astype(np.uint8)
        
    X = pd.DataFrame(X)
    
    if is_train:
        y = df[pd.date_range(t2017, periods=16)].values
        return X, y
    
    if name_prefix is not None:
        X.columns = ['%s_%s' % (name_prefix, c) for c in X.columns]
    
    return X

# %% [markdown]
# 准备训练集

# %%
print("[INFO] Preparing training data...")

t2017 = date(2017, 6, 14)
num_days = 6
X_l, y_l = [], []
for i in range(num_days):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(df_2017, promo_2017, t2017 + delta)
    
    X_tmp2 = prepare_dataset(df_2017_item, promo_2017_item, t2017 + delta, is_train=False, name_prefix='item')
    X_tmp2.index = df_2017_item.index
    X_tmp2 = X_tmp2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)
    
    X_tmp3 = prepare_dataset(df_2017_store_class, promo_2017_store_class, t2017 + delta, is_train=False, name_prefix='store_class')
    X_tmp3.index = df_2017_store_class.index
    X_tmp3 = X_tmp3.reindex(df_2017_store_class_index).reset_index(drop=True)
    
    X_tmp = pd.concat([X_tmp, X_tmp2, X_tmp3, items.reset_index(), stores.reset_index()], axis=1)
    X_l.append(X_tmp)
    y_l.append(y_tmp)
    
    del X_tmp, y_tmp, X_tmp2, X_tmp3
    gc.collect()

X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)

del X_l, y_l
gc.collect()
# Out:
# [INFO] Preparing training data...
# 0

# %% [markdown]
# 准备验证集

# %%
print("[INFO] Preparing validation data...")

X_val, y_val = prepare_dataset(df_2017, promo_2017, date(2017, 7, 26))

X_val2 = prepare_dataset(df_2017_item, promo_2017_item, date(2017, 7, 26), is_train=False, name_prefix='item')
X_val2.index = df_2017_item.index
X_val2 = X_val2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

X_val3 = prepare_dataset(df_2017_store_class, promo_2017_store_class, date(2017, 7, 26), is_train=False, name_prefix='store_class')
X_val3.index = df_2017_store_class.index
X_val3 = X_val3.reindex(df_2017_store_class_index).reset_index(drop=True)

X_val = pd.concat([X_val, X_val2, X_val3, items.reset_index(), stores.reset_index()], axis=1)

del X_val2, X_val3
gc.collect()
# Out:
# [INFO] Preparing validation data...
# 7

# %% [markdown]
# 准备测试集

# %%
print("[INFO] Preparing testing data...")

X_test = prepare_dataset(df_2017, promo_2017, date(2017, 8, 16), is_train=False)

X_test2 = prepare_dataset(df_2017_item, promo_2017_item, date(2017, 8, 16), is_train=False, name_prefix='item')
X_test2.index = df_2017_item.index
X_test2 = X_test2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

X_test3 = prepare_dataset(df_2017_store_class, promo_2017_store_class, date(2017, 8, 16), is_train=False, name_prefix='store_class')
X_test3.index = df_2017_store_class.index
X_test3 = X_test3.reindex(df_2017_store_class_index).reset_index(drop=True)

X_test = pd.concat([X_test, X_test2, X_test3, items.reset_index(), stores.reset_index()], axis=1)

del X_test2, X_test3
gc.collect()
# Out:
# [INFO] Preparing testing data...
# 7

# %% [markdown]
# ## 3 训练模型

# %%
print("[INFO] Start training...")
t0 = time()

params = {
    'num_leaves': 80, 
    'objective': 'regression', 
    'min_data_in_leaf': 200, 
    'learning_rate': 0.02, 
    'feature_fraction': 0.8, 
    'bagging_fraction': 0.7, 
    'bagging_freq': 1, 
    'metric': 'l2', 
    'num_threads': 16
}

MAX_ROUNDS = 5000
val_pred = []
test_pred = []
cate_vars = []
for i in range(16):
    print('=' * 50)
    print("Step %d" % (i + 1))
    print('=' * 50)
    
    dtrain = lgb.Dataset(
        X_train, label=y_train[:, i], 
        categorical_feature=cate_vars, 
        weight=pd.concat([items['perishable']] * num_days) * 0.25 + 1
    )
    dval = lgb.Dataset(
        X_val, label=y_val[:, i], reference=dtrain, 
        categorical_feature=cate_vars, 
        weight=items['perishable'] * 0.25 + 1
    )
    bst = lgb.train(
        params, dtrain, num_boost_round=MAX_ROUNDS, 
        valid_sets=[dtrain, dval], early_stopping_rounds=125, 
        verbose_eval=50
    )
    print('\n'.join(("%s: %.2f" % x) for x in sorted(
        zip(X_train.columns, bst.feature_importance('gain')), key=lambda x: x[1], reverse=True)))
    val_pred.append(
        bst.predict(X_val, num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(
        bst.predict(X_test, num_iteration=bst.best_iteration or MAX_ROUNDS))

print("[INFO] Done in %f seconds." % (time() - t0))
print("[INFO] Training Finished! ( ^ _ ^ ) V")
    
print("Validation mse:", mean_squared_error(y_val, np.array(val_pred).transpose()))

weight = items['perishable'] * 0.25 + 1
err = (y_val - np.array(val_pred).transpose()) ** 2
err = err.sum(axis=1) * weight
err = np.sqrt(err.sum() / weight.sum() / 16)
print("nwrmsle = {}".format(err))

y_val = np.array(val_pred).transpose()
df_preds = pd.DataFrame(
    y_val, index=df_2017.index, 
    columns=pd.date_range('2017-07-26', periods=16)
).stack().to_frame('unit_sales')
df_preds.index.set_names(['store_nbr', 'item_nbr', 'date'], inplace=True)
df_preds['unit_sales'] = np.clip(np.expm1(df_preds['unit_sales']), 0, 1000)
df_preds.reset_index().to_csv('lgb_cv.csv', index=False)
# Out:
# [INFO] Start training...
# ==================================================
# Step 1
# ==================================================
# /root/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1040: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 125 rounds.
# [50]	training's l2: 0.412476	valid_1's l2: 0.403112
# [100]	training's l2: 0.310644	valid_1's l2: 0.30659
# [150]	training's l2: 0.291937	valid_1's l2: 0.290089
# [200]	training's l2: 0.286146	valid_1's l2: 0.28588
# [250]	training's l2: 0.282872	valid_1's l2: 0.283936
# [300]	training's l2: 0.280484	valid_1's l2: 0.282787
# [350]	training's l2: 0.278714	valid_1's l2: 0.282126
# [400]	training's l2: 0.277237	valid_1's l2: 0.281708
# [450]	training's l2: 0.275873	valid_1's l2: 0.28136
# [500]	training's l2: 0.274668	valid_1's l2: 0.281121
# [550]	training's l2: 0.273503	valid_1's l2: 0.280921
# [600]	training's l2: 0.272394	valid_1's l2: 0.280742
# [650]	training's l2: 0.271399	valid_1's l2: 0.280651
# [700]	training's l2: 0.270376	valid_1's l2: 0.280516
# [750]	training's l2: 0.269436	valid_1's l2: 0.280426
# [800]	training's l2: 0.268507	valid_1's l2: 0.280332
# [850]	training's l2: 0.267602	valid_1's l2: 0.280292
# [900]	training's l2: 0.266748	valid_1's l2: 0.280251
# [950]	training's l2: 0.265915	valid_1's l2: 0.280184
# [1000]	training's l2: 0.265066	valid_1's l2: 0.280128
# [1050]	training's l2: 0.264225	valid_1's l2: 0.280075
# [1100]	training's l2: 0.263417	valid_1's l2: 0.28004
# [1150]	training's l2: 0.262629	valid_1's l2: 0.279984
# [1200]	training's l2: 0.261859	valid_1's l2: 0.279962
# [1250]	training's l2: 0.261094	valid_1's l2: 0.279903
# [1300]	training's l2: 0.260334	valid_1's l2: 0.279869
# [1350]	training's l2: 0.259607	valid_1's l2: 0.279823
# [1400]	training's l2: 0.258881	valid_1's l2: 0.2798
# [1450]	training's l2: 0.258184	valid_1's l2: 0.279771
# [1500]	training's l2: 0.257493	valid_1's l2: 0.279738
# [1550]	training's l2: 0.256771	valid_1's l2: 0.279744
# [1600]	training's l2: 0.256069	valid_1's l2: 0.279712
# [1650]	training's l2: 0.255379	valid_1's l2: 0.279702
# [1700]	training's l2: 0.254697	valid_1's l2: 0.279691
# [1750]	training's l2: 0.254016	valid_1's l2: 0.279667
# [1800]	training's l2: 0.253347	valid_1's l2: 0.279676
# [1850]	training's l2: 0.252664	valid_1's l2: 0.279651
# [1900]	training's l2: 0.252011	valid_1's l2: 0.279618
# [1950]	training's l2: 0.251361	valid_1's l2: 0.279609
# [2000]	training's l2: 0.250692	valid_1's l2: 0.279592
# [2050]	training's l2: 0.250058	valid_1's l2: 0.279614
# [2100]	training's l2: 0.249418	valid_1's l2: 0.279602
# [2150]	training's l2: 0.248786	valid_1's l2: 0.279585
# [2200]	training's l2: 0.248166	valid_1's l2: 0.279564
# [2250]	training's l2: 0.247554	valid_1's l2: 0.279557
# [2300]	training's l2: 0.246949	valid_1's l2: 0.27956
# [2350]	training's l2: 0.246326	valid_1's l2: 0.279547
# [2400]	training's l2: 0.245711	valid_1's l2: 0.279543
# [2450]	training's l2: 0.245117	valid_1's l2: 0.27953
# [2500]	training's l2: 0.244525	valid_1's l2: 0.279518
# [2550]	training's l2: 0.243922	valid_1's l2: 0.279513
# [2600]	training's l2: 0.243326	valid_1's l2: 0.279518
# [2650]	training's l2: 0.242738	valid_1's l2: 0.279502
# [2700]	training's l2: 0.242152	valid_1's l2: 0.279497
# [2750]	training's l2: 0.24156	valid_1's l2: 0.279505
# [2800]	training's l2: 0.241	valid_1's l2: 0.279509
# Early stopping, best iteration is:
# [2717]	training's l2: 0.241956	valid_1's l2: 0.279496
# mean_140_decay: 3253547.22
# mean_30_decay: 3028546.98
# mean_7_decay: 2594764.13
# mean_60_decay: 2304935.38
# mean_14_decay: 1597671.64
# mean_7: 615570.40
# promo_0: 444382.17
# mean_20_dow0_2017: 209094.82
# mean_4_dow0_2017: 171431.10
# median_7: 127146.10
# day_1_2017: 101950.80
# no_promo_mean_140_decay: 82545.20
# no_promo_mean_60_decay: 74106.34
# no_promo_mean_7_decay: 68765.77
# no_promo_mean_3_decay: 43808.21
# item_promo_0: 42736.45
# no_promo_mean_3: 40921.88
# has_promo_mean_140: 37453.66
# no_promo_mean_60: 36168.80
# median_14: 34079.79
# no_promo_mean_14_decay: 34015.96
# no_promo_mean_7: 32521.47
# item_diff_30_mean: 29360.93
# has_promo_mean_60: 27446.97
# last_has_sales_day_in_last_7: 26256.96
# std_14: 25756.51
# item_diff_14_mean: 23399.82
# no_promo_mean_140: 23390.61
# first_has_promo_day_in_last_7: 21026.87
# std_7: 21006.82
# store_nbr: 20726.38
# item_diff_60_mean: 20624.48
# item_diff_7_mean: 20479.89
# has_promo_mean_14: 20278.94
# no_promo_mean_30: 18468.05
# has_promo_mean_30: 18105.07
# diff_7_mean: 17775.51
# diff_3_mean: 17555.01
# min_3: 16822.54
# type: 14859.64
# no_promo_mean_30_decay: 14726.34
# item_day_1_2017: 13968.62
# std_3: 13482.54
# promo_7: 12522.05
# diff_14_mean: 12353.95
# item_diff_140_mean: 11506.95
# std_30: 11142.50
# family: 11049.06
# item_diff_3_mean: 10510.77
# std_140: 10146.16
# mean_3_decay: 9752.19
# diff_30_mean: 9719.93
# day_14_2017: 9079.56
# store_class_diff_14_mean_2: 8949.24
# store_class_diff_7_mean_2: 8869.58
# diff_60_mean: 8636.97
# std_60: 8417.93
# mean_20_dow4_2017: 8383.88
# day_7_2017: 8374.85
# std_14_2: 8368.38
# std_30_2: 8360.80
# std_60_2: 8242.59
# has_promo_mean_7: 8234.76
# std_7_2: 8099.87
# mean_20_dow2_2017: 7983.18
# last_has_sales_day_in_last_14: 7877.20
# std_3_2: 7832.61
# std_140_2: 7832.33
# diff_140_mean: 7771.86
# diff_140_mean_2: 7751.33
# store_class_diff_140_mean_2: 7624.35
# item_diff_7_mean_2: 7223.98
# diff_30_mean_2: 7161.50
# store_class_diff_7_mean: 7153.77
# first_has_sales_day_in_last_140: 7063.65
# store_class_diff_140_mean: 7052.68
# diff_14_mean_2: 7044.19
# item_nbr: 6963.75
# no_promo_mean_14: 6960.59
# store_class_promo_0: 6812.22
# store_class_diff_14_mean: 6752.86
# cluster: 6684.18
# has_promo_mean_7_decay: 6683.67
# mean_4_dow2_2017: 6676.56
# diff_7_mean_2: 6557.80
# median_60_2: 6540.57
# first_has_sales_day_in_last_14: 6502.31
# diff_3_mean_2: 6451.38
# store_class_diff_30_mean_2: 6421.85
# diff_60_mean_2: 6247.39
# item_diff_3_mean_2: 6116.19
# store_class_diff_30_mean: 6067.09
# max_7: 6038.64
# median_30_2: 5902.47
# item_has_promo_days_in_last_14: 5825.81
# median_30: 5812.43
# max_3: 5807.78
# store_class_diff_3_mean_2: 5800.05
# item_std_3: 5769.65
# mean_30_2: 5716.30
# item_std_3_2: 5673.35
# day_4_2017: 5661.11
# item_diff_30_mean_2: 5618.82
# item_diff_140_mean_2: 5598.84
# item_no_promo_mean_3: 5506.07
# store_class_diff_3_mean: 5504.72
# day_5_2017: 5484.16
# item_diff_14_mean_2: 5467.42
# item_std_7: 5447.52
# item_diff_60_mean_2: 5436.06
# promo_-7: 5424.96
# day_12_2017: 5394.55
# store_class_diff_60_mean: 5390.59
# class: 5308.24
# store_class_diff_60_mean_2: 5188.95
# first_has_sales_day_in_last_30: 5178.20
# store_class_promo_7: 5085.80
# first_has_sales_day_in_last_7: 5078.94
# has_sales_days_in_last_140: 5034.11
# item_no_promo_mean_3_decay: 4994.77
# max_14: 4980.79
# day_2_2017: 4930.71
# promo_14: 4888.53
# mean_4_dow4_2017: 4887.11
# store_class_promo_14: 4807.61
# mean_4_dow3_2017: 4795.99
# mean_20_dow1_2017: 4784.28
# item_std_14_2: 4676.73
# first_has_promo_day_in_last_140: 4604.57
# mean_4_dow5_2017: 4588.65
# max_30: 4586.39
# mean_4_dow6_2017: 4531.78
# item_day_2_2017: 4527.04
# mean_4_dow1_2017: 4525.54
# day_6_2017: 4519.80
# max_14_2: 4501.81
# mean_20_dow6_2017: 4487.81
# day_3_2017: 4396.81
# item_has_promo_mean_7: 4368.48
# item_std_7_2: 4268.44
# item_has_promo_mean_14: 4259.36
# max_140: 4220.13
# min_7: 4215.86
# city: 4194.39
# first_has_promo_day_in_after_15_days: 4125.26
# day_13_2017: 4103.81
# median_3: 4064.96
# item_std_140: 4041.53
# item_std_14: 4019.61
# item_std_30: 3969.22
# day_9_2017: 3890.15
# store_class_std_3: 3782.53
# day_15_2017: 3755.06
# item_std_140_2: 3730.08
# mean_3_decay_2: 3711.73
# item_first_has_promo_day_in_last_140: 3613.08
# store_class_std_3_2: 3561.85
# item_std_60_2: 3555.17
# day_11_2017: 3525.48
# max_140_2: 3517.50
# item_has_promo_mean_30: 3487.24
# item_promo_140_2017: 3483.74
# has_sales_days_in_last_60: 3459.20
# store_class_has_promo_mean_3: 3437.13
# item_min_3: 3430.60
# item_mean_20_dow4_2017: 3424.62
# mean_20_dow5_2017: 3401.13
# first_has_promo_day_in_last_14: 3383.64
# mean_14_decay_2: 3359.89
# mean_20_dow3_2017: 3237.16
# item_std_60: 3221.46
# store_class_promo_60_2017: 3212.21
# item_no_promo_mean_7: 3207.41
# has_sales_days_in_last_14: 3140.01
# mean_3: 3139.46
# item_std_30_2: 3136.93
# day_10_2017: 3135.00
# store_class_promo_140_2017: 3111.13
# item_min_140: 3110.06
# max_60: 3099.48
# mean_7_decay_2: 3099.46
# max_3_2: 3094.87
# store_class_has_promo_mean_7: 3080.84
# median_7_2: 3052.87
# store_class_no_promo_mean_60: 3051.31
# max_7_2: 3045.95
# store_class_has_promo_days_in_last_140: 3017.14
# has_promo_mean_3: 3015.24
# item_has_promo_mean_140: 3005.95
# max_30_2: 2956.88
# store_class_promo_14_2017_aft: 2932.02
# store_class_no_promo_mean_14: 2893.06
# store_class_no_promo_mean_30: 2892.60
# item_has_promo_days_in_last_140: 2886.37
# item_promo_60_2017: 2855.37
# item_day_5_2017: 2843.33
# item_promo_7: 2756.48
# mean_3_2: 2714.48
# mean_7_2: 2710.43
# item_has_promo_mean_3: 2709.25
# last_has_promo_day_in_after_15_days: 2682.99
# state: 2671.32
# item_has_promo_mean_60: 2639.66
# has_sales_days_in_last_30: 2629.23
# store_class_promo_-14: 2623.26
# item_promo_-1: 2597.50
# store_class_std_7: 2592.39
# first_has_sales_day_in_last_60: 2540.96
# item_min_30_2: 2538.97
# median_60: 2497.36
# max_60_2: 2478.51
# median_14_2: 2475.97
# item_promo_14_2017_aft: 2468.60
# mean_60_2: 2460.36
# store_class_no_promo_mean_140: 2456.01
# day_8_2017: 2446.35
# store_class_no_promo_mean_7: 2434.21
# mean_14_2: 2420.14
# store_class_std_14_2: 2397.49
# promo_140_2017: 2380.76
# item_day_6_2017: 2369.96
# item_no_promo_mean_7_decay: 2333.28
# item_promo_-7: 2321.31
# store_class_std_7_2: 2302.43
# item_promo_7_2017_aft: 2287.71
# store_class_promo_14_2017: 2248.15
# item_min_140_2: 2240.87
# item_first_has_promo_day_in_last_30: 2227.44
# item_min_60: 2218.19
# item_min_60_2: 2203.61
# item_median_3: 2195.18
# item_day_4_2017: 2185.38
# store_class_has_promo_mean_14: 2144.52
# store_class_no_promo_mean_60_decay: 2131.58
# perishable: 2105.31
# store_class_no_promo_mean_3: 2105.15
# promo_7_2017_aft: 2096.78
# mean_140_2: 2084.99
# item_has_promo_mean_14_decay: 2069.73
# item_has_promo_mean_7_decay: 2055.68
# item_promo_-12: 2044.91
# mean_14: 2043.30
# item_min_30: 1997.74
# item_promo_14: 1970.76
# store_class_first_has_promo_day_in_last_140: 1954.19
# has_promo_mean_14_decay: 1934.85
# item_no_promo_mean_14: 1932.74
# item_first_has_promo_day_in_last_60: 1927.02
# item_promo_-14: 1911.49
# item_day_12_2017: 1892.10
# store_class_promo_-7: 1876.68
# mean_140: 1868.64
# store_class_promo_7_2017_aft: 1857.84
# mean_60: 1851.20
# item_min_14_2: 1848.46
# store_class_no_promo_mean_30_decay: 1847.45
# item_day_15_2017: 1843.87
# median_3_2: 1830.91
# promo_14_2017_aft: 1829.00
# item_promo_-16: 1816.36
# item_day_14_2017: 1808.25
# item_has_promo_days_in_after_15_days: 1802.59
# item_promo_-9: 1789.44
# item_has_promo_days_in_last_60: 1774.04
# item_last_has_promo_day_in_after_15_days: 1764.12
# item_min_7: 1762.68
# store_class_has_promo_mean_30: 1708.87
# has_sales_days_in_last_7: 1704.20
# store_class_has_promo_mean_60: 1690.93
# item_max_140: 1672.19
# item_day_7_2017: 1668.72
# store_class_std_30_2: 1640.10
# has_promo_days_in_after_15_days: 1637.99
# item_day_13_2017: 1635.30
# item_first_has_promo_day_in_after_15_days: 1631.43
# store_class_has_promo_days_in_last_60: 1625.82
# store_class_std_60_2: 1616.29
# mean_30: 1599.42
# item_promo_14_2017: 1592.17
# min_3_2: 1586.31
# store_class_no_promo_mean_7_decay: 1580.63
# item_promo_-10: 1576.53
# item_no_promo_mean_14_decay: 1570.73
# store_class_promo_3_2017_aft: 1569.92
# item_promo_-2: 1565.52
# item_has_promo_mean_30_decay: 1557.70
# store_class_no_promo_mean_140_decay: 1557.66
# item_max_140_2: 1537.11
# store_class_std_14: 1515.63
# mean_30_decay_2: 1485.75
# item_day_11_2017: 1484.45
# item_day_10_2017: 1479.87
# item_day_3_2017: 1446.99
# item_has_promo_mean_60_decay: 1443.79
# store_class_no_promo_mean_14_decay: 1442.45
# item_has_promo_days_in_last_30: 1437.88
# first_has_promo_day_in_last_60: 1418.35
# store_class_promo_13: 1403.55
# store_class_day_12_2017: 1394.69
# store_class_day_5_2017: 1388.00
# item_min_14: 1387.86
# store_class_day_15_2017: 1375.22
# store_class_last_has_promo_day_in_after_15_days: 1370.86
# item_day_8_2017: 1353.67
# item_mean_4_dow2_2017: 1353.12
# store_class_min_140: 1346.30
# item_mean_4_dow4_2017: 1330.10
# store_class_promo_9: 1322.67
# item_mean_20_dow3_2017: 1319.66
# store_class_std_30: 1318.90
# item_promo_3_2017_aft: 1317.26
# store_class_day_14_2017: 1311.35
# store_class_day_7_2017: 1308.12
# store_class_min_140_2: 1301.78
# item_no_promo_mean_30: 1296.05
# item_max_3: 1286.58
# item_mean_20_dow2_2017: 1285.64
# item_mean_20_dow0_2017: 1278.80
# store_class_std_140_2: 1276.10
# item_max_7: 1275.86
# item_max_14_2: 1273.76
# first_has_promo_day_in_last_30: 1261.00
# store_class_no_promo_mean_3_decay: 1257.72
# item_no_promo_mean_30_decay: 1257.71
# item_no_promo_mean_60: 1238.98
# store_class_has_promo_mean_7_decay: 1225.67
# item_day_9_2017: 1210.75
# has_promo_mean_3_decay: 1198.27
# store_class_std_140: 1189.90
# item_first_has_promo_day_in_last_14: 1182.59
# store_class_day_2_2017: 1181.00
# store_class_has_promo_mean_140: 1170.23
# item_no_promo_mean_60_decay: 1166.20
# store_class_day_6_2017: 1158.93
# mean_140_decay_2: 1158.60
# item_has_promo_mean_3_decay: 1154.97
# item_mean_20_dow5_2017: 1149.97
# item_no_promo_mean_140: 1147.23
# store_class_day_13_2017: 1142.69
# store_class_first_has_sales_day_in_last_140: 1128.48
# min_14: 1125.59
# item_mean_20_dow6_2017: 1119.36
# store_class_promo_6: 1114.45
# item_max_30: 1109.27
# store_class_promo_15: 1098.95
# store_class_std_60: 1087.71
# last_has_sales_day_in_last_30: 1085.20
# store_class_promo_-1: 1079.73
# item_max_60: 1075.06
# store_class_day_9_2017: 1070.92
# store_class_has_promo_days_in_last_30: 1070.00
# store_class_promo_2: 1061.69
# item_min_7_2: 1060.17
# median_140: 1053.88
# store_class_has_promo_mean_14_decay: 1046.14
# store_class_first_has_promo_day_in_last_30: 1043.60
# store_class_first_has_promo_day_in_last_60: 1040.68
# item_mean_4_dow3_2017: 1036.95
# store_class_promo_11: 1025.96
# item_max_3_2: 1025.07
# has_promo_mean_140_decay: 999.15
# item_median_140_2: 991.70
# item_has_promo_mean_140_decay: 985.07
# store_class_day_4_2017: 983.95
# store_class_promo_-8: 983.53
# item_mean_20_dow1_2017: 982.61
# item_max_60_2: 981.80
# store_class_day_8_2017: 980.07
# item_first_has_promo_day_in_last_7: 978.97
# item_promo_15: 976.37
# store_class_promo_-15: 975.61
# item_max_7_2: 975.43
# item_median_60_2: 971.84
# item_max_30_2: 970.84
# store_class_promo_-10: 968.35
# item_mean_4_dow1_2017: 960.03
# store_class_day_1_2017: 955.92
# item_min_3_2: 943.57
# mean_60_decay_2: 943.11
# item_median_7: 941.43
# promo_60_2017: 935.59
# promo_-15: 930.18
# store_class_has_promo_days_in_after_15_days: 928.90
# item_promo_1: 911.43
# store_class_min_60_2: 905.50
# item_no_promo_mean_140_decay: 898.74
# store_class_promo_-12: 891.56
# store_class_day_11_2017: 888.17
# item_median_3_2: 877.63
# median_140_2: 875.48
# has_promo_mean_60_decay: 860.93
# item_median_30_2: 840.85
# store_class_min_3: 832.73
# store_class_min_30_2: 830.06
# store_class_has_promo_mean_3_decay: 825.52
# item_mean_4_dow5_2017: 814.46
# item_mean_4_dow0_2017: 801.67
# store_class_mean_20_dow2_2017: 800.73
# store_class_promo_8: 799.57
# item_mean_3: 791.09
# store_class_promo_-6: 790.01
# store_class_promo_-13: 789.63
# item_promo_6: 784.87
# min_7_2: 774.69
# item_max_14: 771.30
# item_mean_3_decay: 765.24
# store_class_min_3_2: 763.30
# item_promo_-8: 760.05
# promo_-14: 757.16
# item_promo_-13: 750.62
# item_promo_-6: 746.03
# store_class_mean_4_dow0_2017: 745.04
# store_class_day_3_2017: 744.99
# store_class_min_14_2: 744.87
# store_class_min_60: 738.26
# item_promo_-15: 729.96
# item_promo_-4: 729.92
# item_promo_3: 729.71
# item_promo_11: 729.40
# store_class_has_promo_mean_30_decay: 727.22
# item_promo_9: 726.21
# store_class_min_14: 724.55
# has_promo_mean_30_decay: 718.74
# store_class_promo_-5: 718.33
# item_has_sales_days_in_last_140: 715.07
# store_class_mean_4_dow2_2017: 712.24
# store_class_promo_12: 711.74
# item_median_14_2: 710.96
# store_class_mean_20_dow4_2017: 704.00
# store_class_promo_10: 700.37
# store_class_has_sales_days_in_last_140: 694.12
# item_promo_13: 687.80
# item_median_7_2: 683.75
# item_median_60: 677.69
# item_median_140: 672.28
# store_class_min_7: 672.07
# store_class_day_10_2017: 671.82
# store_class_min_7_2: 671.28
# has_promo_days_in_last_7: 669.22
# store_class_promo_-9: 665.14
# store_class_promo_4: 663.54
# item_mean_140_2: 660.99
# store_class_median_3: 660.94
# item_promo_8: 660.01
# store_class_promo_1: 657.34
# store_class_mean_20_dow0_2017: 656.35
# store_class_first_has_promo_day_in_after_15_days: 655.79
# store_class_promo_-16: 651.35
# item_mean_4_dow6_2017: 648.56
# item_promo_-5: 645.22
# store_class_max_3: 636.65
# item_mean_3_decay_2: 624.75
# store_class_promo_-2: 614.85
# store_class_promo_-3: 613.56
# has_promo_days_in_last_30: 603.16
# item_promo_2: 601.72
# store_class_has_promo_mean_60_decay: 599.61
# store_class_min_30: 592.82
# promo_3_2017_aft: 591.17
# item_last_has_promo_day_in_last_7: 588.49
# item_mean_60_2: 585.49
# item_promo_4: 581.00
# store_class_promo_5: 580.59
# store_class_mean_20_dow3_2017: 578.69
# store_class_promo_3: 571.63
# item_mean_7_decay: 569.69
# store_class_promo_-4: 569.35
# store_class_mean_4_dow5_2017: 556.98
# store_class_mean_4_dow4_2017: 556.56
# item_mean_140: 553.43
# item_median_14: 544.25
# promo_14_2017: 540.37
# item_mean_30_2: 540.21
# store_class_mean_4_dow1_2017: 538.05
# item_mean_60: 536.08
# store_class_first_has_promo_day_in_last_14: 533.96
# store_class_median_3_2: 519.92
# store_class_has_promo_mean_140_decay: 518.00
# item_mean_3_2: 514.01
# has_promo_days_in_last_140: 510.31
# store_class_max_3_2: 502.92
# store_class_max_140_2: 501.12
# store_class_promo_-11: 497.00
# item_mean_14_2: 484.84
# item_promo_5: 479.37
# promo_-8: 472.82
# store_class_max_7: 471.34
# item_mean_7_decay_2: 467.79
# store_class_max_140: 464.98
# min_14_2: 463.45
# store_class_mean_20_dow5_2017: 458.11
# store_class_mean_20_dow6_2017: 451.21
# store_class_max_7_2: 450.33
# item_promo_-3: 448.93
# item_mean_7: 446.01
# store_class_first_has_promo_day_in_last_7: 441.29
# last_has_promo_day_in_last_140: 435.63
# item_promo_12: 434.70
# item_promo_-11: 427.53
# store_class_mean_4_dow6_2017: 416.79
# store_class_max_14_2: 410.67
# promo_1: 402.60
# store_class_mean_4_dow3_2017: 399.85
# store_class_median_7: 389.94
# item_mean_7_2: 385.90
# store_class_mean_20_dow1_2017: 385.42
# store_class_max_60_2: 381.21
# item_promo_10: 379.28
# store_class_max_14: 376.87
# item_median_30: 362.88
# store_class_last_has_promo_day_in_last_7: 361.45
# store_class_median_7_2: 358.96
# item_mean_14_decay: 351.58
# store_class_max_30: 350.79
# store_class_has_promo_days_in_last_14: 337.61
# store_class_max_60: 335.90
# item_mean_14: 327.01
# min_30: 313.27
# item_mean_14_decay_2: 311.61
# store_class_max_30_2: 306.03
# item_mean_30: 305.53
# item_has_promo_days_in_last_7: 291.08
# item_first_has_sales_day_in_last_140: 278.00
# store_class_mean_3_2: 277.87
# last_has_promo_day_in_last_7: 269.50
# item_mean_30_decay_2: 268.59
# item_has_sales_days_in_last_60: 255.04
# store_class_mean_7_decay_2: 254.65
# store_class_median_14_2: 254.08
# store_class_median_140_2: 253.84
# store_class_median_140: 253.74
# store_class_mean_3_decay_2: 249.49
# store_class_mean_3_decay: 246.28
# min_30_2: 245.82
# store_class_mean_3: 242.09
# last_has_promo_day_in_last_30: 240.87
# last_has_promo_day_in_last_60: 231.30
# store_class_median_14: 230.82
# item_last_has_promo_day_in_last_30: 228.66
# item_mean_60_decay_2: 227.63
# item_last_has_promo_day_in_last_14: 222.54
# item_last_has_promo_day_in_last_60: 220.50
# item_mean_60_decay: 215.80
# item_mean_30_decay: 213.26
# store_class_mean_7_decay: 206.90
# has_promo_days_in_last_60: 196.44
# promo_2: 183.04
# store_class_mean_60_2: 176.10
# store_class_mean_7_2: 171.49
# item_last_has_promo_day_in_last_140: 160.92
# item_first_has_sales_day_in_last_60: 159.70
# store_class_median_60_2: 156.44
# min_60: 156.26
# promo_-11: 155.65
# promo_6: 152.34
# store_class_mean_7: 149.69
# store_class_mean_30_2: 148.87
# store_class_mean_140_2: 147.24
# item_mean_140_decay: 147.16
# store_class_mean_14_2: 144.22
# promo_9: 136.38
# min_60_2: 132.20
# last_has_promo_day_in_last_14: 132.17
# item_mean_140_decay_2: 128.45
# store_class_last_has_promo_day_in_last_140: 116.69
# store_class_mean_140: 114.28
# store_class_median_30_2: 112.80
# store_class_last_has_promo_day_in_last_30: 109.58
# store_class_mean_30_decay: 107.90
# item_has_sales_days_in_last_30: 106.08
# store_class_median_30: 105.85
# store_class_last_has_promo_day_in_last_60: 99.74
# promo_11: 98.26
# promo_-5: 96.41
# store_class_last_has_promo_day_in_last_14: 95.18
# promo_8: 94.02
# store_class_mean_60: 91.35
# store_class_mean_14_decay_2: 88.34
# store_class_mean_14_decay: 87.21
# store_class_median_60: 85.92
# store_class_has_promo_days_in_last_7: 84.46
# promo_4: 74.27
# store_class_has_sales_days_in_last_60: 65.95
# promo_13: 59.35
# store_class_mean_140_decay_2: 57.58
# store_class_mean_30: 55.53
# store_class_mean_14: 49.98
# store_class_mean_30_decay_2: 48.78
# last_has_sales_day_in_last_140: 48.72
# promo_3: 43.57
# store_class_mean_60_decay_2: 40.01
# has_promo_days_in_last_14: 39.67
# promo_-10: 30.77
# min_140: 30.21
# item_first_has_sales_day_in_last_30: 30.17
# promo_-4: 28.86
# store_class_has_sales_days_in_last_14: 26.51
# store_class_mean_60_decay: 25.94
# promo_5: 22.23
# promo_-6: 21.68
# promo_-9: 19.78
# min_140_2: 18.93
# store_class_first_has_sales_day_in_last_14: 18.19
# promo_-3: 15.72
# last_has_sales_day_in_last_60: 14.73
# promo_12: 14.52
# promo_-13: 14.42
# promo_-12: 14.30
# store_class_has_sales_days_in_last_30: 13.34
# promo_-16: 12.97
# store_class_first_has_sales_day_in_last_60: 12.59
# store_class_has_sales_days_in_last_7: 12.10
# store_class_first_has_sales_day_in_last_30: 11.99
# store_class_mean_140_decay: 8.53
# item_has_sales_days_in_last_14: 6.07
# store_class_first_has_sales_day_in_last_7: 5.37
# promo_-2: 3.13
# promo_15: 2.95
# promo_10: 2.60
# promo_-1: 0.00
# item_has_sales_days_in_last_7: 0.00
# item_last_has_sales_day_in_last_7: 0.00
# item_first_has_sales_day_in_last_7: 0.00
# item_last_has_sales_day_in_last_14: 0.00
# item_first_has_sales_day_in_last_14: 0.00
# item_last_has_sales_day_in_last_30: 0.00
# item_last_has_sales_day_in_last_60: 0.00
# item_last_has_sales_day_in_last_140: 0.00
# store_class_last_has_sales_day_in_last_7: 0.00
# store_class_last_has_sales_day_in_last_14: 0.00
# store_class_last_has_sales_day_in_last_30: 0.00
# store_class_last_has_sales_day_in_last_60: 0.00
# store_class_last_has_sales_day_in_last_140: 0.00
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [50]	training's l2: 0.413245	valid_1's l2: 0.418767
# [100]	training's l2: 0.328991	valid_1's l2: 0.337099
# [150]	training's l2: 0.313397	valid_1's l2: 0.322532
# [200]	training's l2: 0.307917	valid_1's l2: 0.317753
# [250]	training's l2: 0.304656	valid_1's l2: 0.315537
# [300]	training's l2: 0.302219	valid_1's l2: 0.314195
# [350]	training's l2: 0.300275	valid_1's l2: 0.313315
# [400]	training's l2: 0.298594	valid_1's l2: 0.312795
# [450]	training's l2: 0.297037	valid_1's l2: 0.312278
# [500]	training's l2: 0.295658	valid_1's l2: 0.311929
# [550]	training's l2: 0.294363	valid_1's l2: 0.31165
# [600]	training's l2: 0.293152	valid_1's l2: 0.311369
# [650]	training's l2: 0.292012	valid_1's l2: 0.311143
# [700]	training's l2: 0.290909	valid_1's l2: 0.311042
# [750]	training's l2: 0.289868	valid_1's l2: 0.310954
# [800]	training's l2: 0.288851	valid_1's l2: 0.310892
# [850]	training's l2: 0.28785	valid_1's l2: 0.310839
# [900]	training's l2: 0.286903	valid_1's l2: 0.310723
# [950]	training's l2: 0.285953	valid_1's l2: 0.310653
# [1000]	training's l2: 0.285036	valid_1's l2: 0.310632
# [1050]	training's l2: 0.284135	valid_1's l2: 0.310595
# [1100]	training's l2: 0.28325	valid_1's l2: 0.310529
# [1150]	training's l2: 0.282399	valid_1's l2: 0.310505
# [1200]	training's l2: 0.281542	valid_1's l2: 0.310517
# [1250]	training's l2: 0.2807	valid_1's l2: 0.310472
# [1300]	training's l2: 0.279869	valid_1's l2: 0.310428
# [1350]	training's l2: 0.279044	valid_1's l2: 0.310401
# [1400]	training's l2: 0.278218	valid_1's l2: 0.310369
# [1450]	training's l2: 0.277439	valid_1's l2: 0.310322
# [1500]	training's l2: 0.276658	valid_1's l2: 0.310346
# [1550]	training's l2: 0.275884	valid_1's l2: 0.310333
# Early stopping, best iteration is:
# [1441]	training's l2: 0.277576	valid_1's l2: 0.31031
# mean_140_decay: 5104658.38
# mean_60_decay: 4207157.12
# mean_7: 711590.51
# mean_7_decay: 596338.16
# mean_14_decay: 491126.96
# mean_30_decay: 334612.28
# first_has_promo_day_in_after_15_days: 197078.29
# median_7: 170826.18
# mean_20_dow1_2017: 155328.40
# promo_1: 115491.76
# mean_4_dow1_2017: 74630.84
# no_promo_mean_60: 65019.38
# item_promo_1: 53328.09
# median_60: 45998.93
# median_14: 40464.28
# item_diff_30_mean: 36410.91
# no_promo_mean_7_decay: 31325.27
# no_promo_mean_3_decay: 25013.86
# no_promo_mean_30: 22945.81
# promo_7_2017_aft: 22887.39
# item_diff_7_mean: 22287.72
# no_promo_mean_140: 22076.41
# no_promo_mean_14_decay: 20720.98
# has_promo_mean_14: 20595.28
# item_diff_14_mean: 18693.03
# no_promo_mean_60_decay: 18364.08
# no_promo_mean_140_decay: 18324.11
# has_promo_mean_140: 16484.12
# std_14: 15483.36
# mean_20_dow2_2017: 14783.60
# no_promo_mean_30_decay: 14210.77
# has_promo_mean_7: 13276.04
# std_7: 12552.52
# has_promo_mean_30: 12424.93
# item_diff_60_mean: 12372.04
# no_promo_mean_14: 12279.76
# no_promo_mean_3: 11882.85
# day_1_2017: 11001.88
# item_promo_0: 10455.69
# item_day_1_2017: 10235.56
# std_30: 10172.72
# mean_4_dow2_2017: 10125.17
# diff_7_mean: 9951.45
# item_day_5_2017: 9690.41
# promo_0: 9536.17
# item_diff_140_mean: 9370.03
# no_promo_mean_7: 9313.68
# last_has_sales_day_in_last_7: 9160.01
# std_60: 8631.40
# std_140: 8513.34
# item_diff_7_mean_2: 8503.64
# has_promo_mean_60: 8437.12
# diff_3_mean: 8330.03
# median_60_2: 8199.97
# item_diff_3_mean: 7999.15
# mean_20_dow4_2017: 7569.10
# std_3: 7490.36
# day_13_2017: 7171.57
# item_diff_3_mean_2: 6945.99
# store_nbr: 6888.53
# std_30_2: 6759.11
# day_6_2017: 6748.40
# item_std_7_2: 6661.02
# std_60_2: 6563.49
# diff_14_mean: 6522.12
# day_12_2017: 6513.72
# std_140_2: 6479.48
# item_diff_30_mean_2: 6400.55
# diff_30_mean: 6344.84
# std_14_2: 6078.20
# diff_60_mean: 6064.86
# store_class_diff_3_mean_2: 5867.99
# store_class_diff_3_mean: 5748.30
# item_promo_3_2017_aft: 5329.67
# class: 5266.84
# std_7_2: 5262.84
# has_promo_days_in_after_15_days: 5238.58
# first_has_sales_day_in_last_14: 5203.98
# max_14: 5136.31
# day_5_2017: 5104.72
# store_class_diff_140_mean: 5084.09
# item_std_3_2: 4936.00
# mean_4_dow4_2017: 4932.74
# std_3_2: 4831.04
# diff_140_mean: 4760.28
# min_3: 4751.91
# item_diff_60_mean_2: 4690.29
# item_nbr: 4613.51
# item_std_7: 4529.56
# item_diff_14_mean_2: 4513.13
# store_class_diff_7_mean_2: 4445.89
# max_7: 4434.68
# mean_3_decay: 4418.76
# item_std_3: 4406.11
# promo_14_2017_aft: 4397.03
# family: 4318.62
# item_diff_140_mean_2: 4184.99
# median_3: 4180.89
# diff_140_mean_2: 4129.25
# promo_3_2017_aft: 3999.27
# diff_30_mean_2: 3996.09
# item_promo_7_2017_aft: 3884.99
# diff_3_mean_2: 3805.76
# item_no_promo_mean_3: 3757.10
# diff_60_mean_2: 3732.25
# mean_30_2: 3731.99
# mean_4_dow0_2017: 3731.75
# max_14_2: 3727.59
# first_has_sales_day_in_last_140: 3711.16
# diff_14_mean_2: 3689.39
# store_class_diff_30_mean_2: 3670.68
# store_class_diff_14_mean: 3599.61
# item_std_14: 3500.99
# store_class_diff_30_mean: 3458.58
# item_promo_60_2017: 3401.27
# first_has_sales_day_in_last_30: 3377.47
# item_mean_20_dow4_2017: 3365.82
# item_no_promo_mean_7: 3364.18
# day_4_2017: 3321.65
# store_class_diff_7_mean: 3297.45
# diff_7_mean_2: 3272.27
# max_3: 3268.27
# item_no_promo_mean_3_decay: 3248.87
# max_140: 3241.74
# first_has_sales_day_in_last_7: 3237.62
# item_has_promo_mean_14: 3235.64
# item_min_14_2: 3205.34
# store_class_diff_140_mean_2: 3189.45
# has_promo_mean_7_decay: 3178.94
# has_sales_days_in_last_30: 3150.92
# item_std_14_2: 3112.97
# mean_20_dow0_2017: 3103.81
# day_2_2017: 3082.56
# last_has_sales_day_in_last_14: 3064.90
# item_std_30_2: 3050.46
# item_promo_3: 3047.44
# store_class_diff_60_mean_2: 3015.99
# item_std_140_2: 3011.76
# median_30_2: 3005.77
# item_std_60_2: 2976.33
# store_class_diff_60_mean: 2954.13
# max_30: 2939.37
# item_day_13_2017: 2870.53
# item_has_promo_mean_7: 2850.70
# first_has_sales_day_in_last_60: 2841.00
# store_class_diff_14_mean_2: 2778.71
# mean_4_dow5_2017: 2748.70
# max_60: 2730.06
# mean_14_2: 2724.33
# has_sales_days_in_last_140: 2718.00
# item_std_140: 2659.70
# item_promo_140_2017: 2657.73
# item_first_has_promo_day_in_last_30: 2655.10
# item_no_promo_mean_7_decay: 2647.48
# item_min_60: 2638.95
# item_min_140: 2634.33
# item_std_60: 2622.96
# mean_14_decay_2: 2600.88
# item_std_30: 2600.32
# store_class_has_promo_days_in_last_140: 2586.32
# mean_4_dow3_2017: 2552.16
# mean_60_2: 2516.98
# mean_3: 2506.79
# day_3_2017: 2502.32
# day_15_2017: 2495.07
# day_11_2017: 2447.91
# mean_4_dow6_2017: 2434.01
# item_has_promo_mean_3: 2389.49
# mean_7_decay_2: 2382.46
# item_min_3: 2376.92
# max_140_2: 2352.72
# item_promo_14_2017: 2327.01
# day_14_2017: 2275.01
# mean_20_dow5_2017: 2253.66
# city: 2241.25
# has_sales_days_in_last_14: 2216.94
# item_min_30_2: 2209.62
# item_day_4_2017: 2164.78
# item_promo_14_2017_aft: 2153.33
# max_30_2: 2148.35
# day_9_2017: 2133.12
# promo_140_2017: 2132.01
# state: 2128.11
# mean_3_decay_2: 2118.59
# day_10_2017: 2115.91
# item_no_promo_mean_14: 2114.44
# item_min_30: 2096.41
# item_day_6_2017: 2093.41
# mean_20_dow3_2017: 2091.07
# max_60_2: 2089.04
# item_first_has_promo_day_in_last_140: 2085.40
# mean_20_dow6_2017: 2065.49
# item_has_promo_days_in_last_140: 2054.82
# median_30: 2034.34
# store_class_promo_60_2017: 2034.15
# has_sales_days_in_last_60: 2005.19
# day_7_2017: 1996.81
# item_min_140_2: 1983.02
# mean_7_2: 1977.62
# store_class_promo_14_2017_aft: 1974.27
# item_min_7: 1969.94
# store_class_promo_140_2017: 1968.02
# store_class_has_promo_mean_3: 1958.19
# item_has_promo_mean_140: 1942.22
# item_day_10_2017: 1935.05
# item_has_promo_mean_30: 1910.58
# store_class_std_3: 1884.69
# item_min_60_2: 1880.76
# cluster: 1876.97
# item_promo_-1: 1872.62
# item_has_promo_mean_60: 1870.65
# item_promo_4: 1868.73
# item_day_12_2017: 1838.00
# store_class_std_3_2: 1830.14
# max_3_2: 1821.77
# median_14_2: 1805.50
# item_last_has_promo_day_in_after_15_days: 1781.24
# median_140: 1776.73
# item_first_has_promo_day_in_after_15_days: 1774.00
# max_7_2: 1770.08
# store_class_has_promo_mean_7: 1767.09
# first_has_promo_day_in_last_140: 1751.47
# item_mean_4_dow4_2017: 1733.38
# item_first_has_promo_day_in_last_60: 1712.55
# store_class_no_promo_mean_30: 1700.39
# store_class_no_promo_mean_14: 1681.01
# item_day_2_2017: 1624.95
# item_promo_7: 1621.28
# item_promo_-14: 1608.61
# item_has_promo_days_in_after_15_days: 1589.75
# has_promo_mean_14_decay: 1573.49
# mean_3_2: 1569.87
# day_8_2017: 1560.22
# store_class_no_promo_mean_3: 1545.03
# store_class_no_promo_mean_7: 1524.72
# item_day_15_2017: 1507.16
# item_promo_-7: 1497.39
# item_day_3_2017: 1480.06
# store_class_promo_7_2017_aft: 1449.23
# has_promo_mean_3: 1439.89
# item_has_promo_days_in_last_60: 1433.00
# item_day_14_2017: 1428.20
# store_class_promo_14_2017: 1425.17
# median_3_2: 1410.06
# store_class_day_13_2017: 1408.83
# item_day_9_2017: 1398.70
# store_class_promo_7: 1369.23
# item_has_promo_mean_14_decay: 1348.88
# store_class_std_7_2: 1343.56
# store_class_no_promo_mean_60: 1331.02
# store_class_no_promo_mean_14_decay: 1325.99
# median_7_2: 1324.58
# mean_14: 1316.75
# item_no_promo_mean_14_decay: 1309.12
# store_class_promo_14: 1304.74
# item_mean_20_dow5_2017: 1304.39
# store_class_no_promo_mean_140: 1303.72
# store_class_has_promo_days_in_last_60: 1295.09
# store_class_std_7: 1270.73
# store_class_promo_3_2017_aft: 1264.44
# item_has_promo_mean_7_decay: 1249.78
# item_day_11_2017: 1240.76
# mean_30: 1229.77
# item_max_140: 1228.86
# store_class_has_promo_mean_14: 1228.47
# mean_60: 1224.94
# item_promo_14: 1215.44
# item_promo_-13: 1209.99
# item_promo_5: 1190.18
# item_max_140_2: 1164.55
# item_median_3: 1160.19
# item_has_promo_mean_30_decay: 1148.42
# item_no_promo_mean_30: 1145.58
# item_min_14: 1144.96
# item_promo_2: 1142.65
# store_class_promo_1: 1140.34
# has_sales_days_in_last_7: 1131.23
# min_7: 1123.36
# store_class_no_promo_mean_30_decay: 1115.89
# store_class_promo_-14: 1114.66
# item_day_8_2017: 1104.32
# item_mean_4_dow2_2017: 1103.28
# item_promo_6: 1102.97
# promo_60_2017: 1086.25
# store_class_std_14_2: 1082.42
# median_140_2: 1081.61
# item_min_7_2: 1073.10
# mean_30_decay_2: 1068.77
# store_class_promo_0: 1065.17
# last_has_promo_day_in_after_15_days: 1059.73
# mean_140_2: 1057.81
# item_max_3: 1051.88
# min_3_2: 1051.69
# item_min_3_2: 1044.94
# item_first_has_promo_day_in_last_14: 1043.61
# store_class_first_has_promo_day_in_last_140: 1039.28
# first_has_promo_day_in_last_7: 1019.72
# store_class_promo_8: 1017.94
# has_promo_mean_30_decay: 1008.12
# item_max_7: 1006.87
# store_class_promo_9: 1004.17
# item_no_promo_mean_140: 996.97
# item_day_7_2017: 995.12
# mean_140: 990.96
# item_max_14_2: 975.46
# store_class_no_promo_mean_60_decay: 959.35
# item_mean_4_dow3_2017: 953.50
# mean_140_decay_2: 943.57
# item_no_promo_mean_30_decay: 936.17
# item_mean_20_dow2_2017: 933.26
# store_class_std_60_2: 932.57
# item_last_has_promo_day_in_last_30: 930.01
# store_class_promo_6: 927.19
# has_promo_days_in_last_30: 925.18
# first_has_promo_day_in_last_60: 914.43
# item_no_promo_mean_60: 910.28
# item_mean_20_dow0_2017: 906.14
# item_promo_8: 905.00
# store_class_promo_-7: 888.64
# item_median_140_2: 888.05
# store_class_std_14: 881.64
# store_class_no_promo_mean_7_decay: 880.35
# item_has_promo_days_in_last_30: 877.63
# item_mean_20_dow6_2017: 876.88
# store_class_promo_13: 876.18
# has_promo_mean_3_decay: 871.82
# item_mean_20_dow1_2017: 867.56
# store_class_no_promo_mean_140_decay: 867.44
# has_promo_mean_60_decay: 863.87
# item_median_60_2: 860.21
# item_no_promo_mean_60_decay: 855.68
# item_max_7_2: 852.39
# item_max_3_2: 851.31
# item_mean_20_dow3_2017: 850.37
# store_class_has_promo_days_in_last_30: 847.32
# store_class_min_140_2: 839.95
# store_class_std_30: 833.33
# item_mean_4_dow1_2017: 828.43
# item_median_3_2: 824.95
# item_max_30_2: 818.14
# store_class_no_promo_mean_3_decay: 814.00
# item_has_promo_mean_60_decay: 813.66
# store_class_has_promo_mean_140: 806.01
# store_class_has_promo_mean_30: 805.20
# item_median_14: 802.13
# item_max_60: 799.24
# item_median_30_2: 790.58
# item_median_140: 787.79
# first_has_promo_day_in_last_30: 787.74
# item_promo_-15: 782.53
# item_median_7: 776.93
# store_class_std_60: 769.91
# item_promo_-2: 767.10
# mean_60_decay_2: 765.17
# store_class_promo_-15: 751.68
# item_promo_11: 750.50
# store_class_has_promo_mean_60: 749.44
# store_class_day_6_2017: 747.96
# store_class_day_7_2017: 731.06
# item_median_60: 729.72
# store_class_day_15_2017: 728.36
# item_mean_4_dow5_2017: 728.14
# store_class_promo_-5: 727.28
# item_mean_60_2: 721.44
# item_max_14: 718.39
# item_mean_4_dow0_2017: 715.34
# store_class_std_30_2: 711.31
# item_has_sales_days_in_last_140: 699.43
# type: 693.45
# item_mean_3_decay: 689.54
# store_class_min_140: 686.37
# item_has_promo_mean_140_decay: 685.15
# item_promo_15: 680.07
# store_class_promo_-16: 673.96
# promo_3: 672.37
# store_class_has_promo_mean_7_decay: 670.68
# item_mean_3: 669.20
# store_class_day_12_2017: 669.07
# store_class_std_140_2: 659.71
# item_mean_4_dow6_2017: 652.28
# item_max_30: 644.33
# store_class_promo_15: 642.34
# item_mean_3_2: 639.43
# store_class_std_140: 632.61
# item_promo_9: 625.56
# store_class_day_14_2017: 617.00
# item_has_promo_mean_3_decay: 610.11
# item_median_7_2: 610.00
# store_class_day_3_2017: 609.51
# store_class_has_promo_days_in_after_15_days: 600.87
# item_no_promo_mean_140_decay: 600.65
# last_has_sales_day_in_last_30: 600.32
# store_class_promo_-12: 597.36
# item_promo_13: 593.77
# min_7_2: 589.51
# store_class_promo_2: 587.73
# store_class_promo_-13: 580.50
# store_class_day_5_2017: 577.33
# item_promo_-5: 573.37
# item_promo_-6: 568.58
# store_class_day_2_2017: 567.98
# item_max_60_2: 564.22
# store_class_has_promo_mean_14_decay: 554.44
# first_has_promo_day_in_last_14: 540.08
# store_class_day_11_2017: 536.57
# has_promo_mean_140_decay: 524.04
# item_median_30: 518.58
# item_mean_30_2: 516.48
# item_median_14_2: 512.55
# store_class_promo_11: 508.94
# store_class_day_8_2017: 504.73
# store_class_min_60: 503.25
# store_class_first_has_promo_day_in_last_30: 502.68
# item_promo_-16: 500.95
# store_class_promo_4: 493.17
# promo_14_2017: 492.15
# store_class_promo_12: 484.79
# store_class_day_4_2017: 480.98
# store_class_has_sales_days_in_last_140: 474.35
# store_class_promo_-6: 472.00
# store_class_has_promo_mean_3_decay: 468.09
# store_class_promo_3: 460.96
# item_mean_7_decay: 454.73
# item_last_has_promo_day_in_last_7: 451.42
# item_mean_3_decay_2: 450.10
# store_class_day_1_2017: 446.20
# store_class_promo_-8: 446.03
# store_class_first_has_sales_day_in_last_140: 444.93
# item_promo_-12: 441.40
# perishable: 434.85
# store_class_has_promo_mean_30_decay: 434.42
# store_class_first_has_promo_day_in_after_15_days: 434.23
# store_class_min_14_2: 432.60
# store_class_last_has_promo_day_in_after_15_days: 431.70
# item_mean_14_2: 431.48
# store_class_mean_20_dow4_2017: 426.88
# store_class_day_9_2017: 424.94
# store_class_first_has_promo_day_in_last_60: 416.83
# item_mean_60: 413.92
# item_mean_140_2: 405.09
# store_class_promo_-10: 401.22
# store_class_promo_10: 399.97
# store_class_has_promo_mean_140_decay: 397.87
# last_has_promo_day_in_last_7: 396.40
# promo_-2: 394.15
# store_class_promo_-1: 390.64
# item_mean_7_decay_2: 380.98
# item_mean_7: 379.27
# item_first_has_promo_day_in_last_7: 378.65
# store_class_day_10_2017: 374.72
# min_14: 373.33
# store_class_min_3: 373.20
# item_promo_-4: 371.24
# promo_2: 370.14
# item_has_promo_days_in_last_14: 369.19
# store_class_mean_20_dow1_2017: 366.86
# store_class_mean_4_dow2_2017: 366.86
# promo_4: 365.69
# item_promo_10: 365.37
# store_class_mean_4_dow4_2017: 365.23
# store_class_mean_20_dow0_2017: 364.36
# store_class_min_3_2: 363.48
# store_class_has_promo_days_in_last_14: 362.74
# store_class_median_3: 349.22
# min_14_2: 341.89
# store_class_min_7: 338.06
# store_class_min_7_2: 337.70
# has_promo_days_in_last_140: 337.24
# store_class_min_60_2: 335.66
# store_class_mean_4_dow0_2017: 334.82
# store_class_median_140_2: 334.00
# store_class_mean_4_dow1_2017: 333.06
# item_promo_-8: 332.73
# store_class_has_promo_mean_60_decay: 332.64
# item_promo_-10: 327.18
# item_mean_7_2: 315.84
# store_class_min_30_2: 311.27
# has_promo_days_in_last_7: 310.74
# store_class_first_has_promo_day_in_last_14: 310.28
# store_class_min_30: 307.87
# store_class_promo_-9: 304.73
# store_class_promo_-11: 304.18
# store_class_promo_5: 301.93
# store_class_median_3_2: 298.03
# item_promo_-3: 297.71
# store_class_max_3: 292.96
# store_class_min_14: 292.02
# store_class_promo_-3: 291.88
# store_class_max_7: 290.78
# store_class_first_has_promo_day_in_last_7: 288.26
# store_class_mean_4_dow5_2017: 288.11
# item_promo_-11: 286.70
# store_class_max_140: 286.21
# item_promo_12: 286.15
# store_class_mean_20_dow2_2017: 281.73
# last_has_promo_day_in_last_14: 274.09
# store_class_mean_20_dow3_2017: 269.05
# item_mean_14_decay_2: 267.81
# item_has_sales_days_in_last_60: 264.94
# item_mean_14: 263.08
# store_class_mean_20_dow5_2017: 261.65
# store_class_max_3_2: 259.72
# store_class_mean_4_dow6_2017: 259.21
# item_has_sales_days_in_last_30: 255.31
# store_class_max_14_2: 251.97
# item_mean_140: 249.61
# store_class_mean_20_dow6_2017: 248.88
# last_has_promo_day_in_last_140: 247.78
# store_class_mean_4_dow3_2017: 239.39
# item_first_has_sales_day_in_last_140: 235.39
# store_class_promo_-2: 234.84
# min_30_2: 221.17
# item_mean_30: 219.24
# item_promo_-9: 216.85
# store_class_median_7: 216.53
# store_class_max_140_2: 215.95
# store_class_promo_-4: 214.06
# store_class_max_30_2: 209.46
# has_promo_days_in_last_60: 207.48
# item_mean_14_decay: 206.70
# item_mean_60_decay: 205.69
# last_has_promo_day_in_last_60: 199.75
# item_mean_30_decay: 197.08
# store_class_mean_3_decay_2: 192.48
# store_class_max_7_2: 186.98
# promo_8: 186.52
# store_class_max_30: 185.50
# item_last_has_promo_day_in_last_60: 183.15
# store_class_max_14: 175.76
# item_mean_30_decay_2: 172.44
# item_has_promo_days_in_last_7: 168.29
# promo_7: 168.17
# item_mean_60_decay_2: 168.08
# store_class_last_has_promo_day_in_last_140: 167.83
# last_has_promo_day_in_last_30: 164.05
# store_class_max_60: 161.03
# promo_-6: 157.89
# item_last_has_promo_day_in_last_14: 153.60
# store_class_max_60_2: 153.24
# item_first_has_sales_day_in_last_60: 149.63
# store_class_mean_3_decay: 149.57
# store_class_median_7_2: 144.49
# promo_9: 142.79
# promo_6: 141.50
# store_class_median_140: 122.65
# store_class_last_has_promo_day_in_last_14: 118.38
# store_class_mean_3_2: 115.59
# promo_-15: 113.86
# item_mean_140_decay: 113.01
# store_class_mean_140_2: 111.37
# store_class_mean_7: 109.21
# store_class_last_has_promo_day_in_last_7: 108.56
# item_last_has_promo_day_in_last_140: 104.68
# store_class_mean_3: 104.21
# promo_5: 103.84
# last_has_sales_day_in_last_60: 103.43
# store_class_median_30_2: 103.05
# store_class_last_has_promo_day_in_last_60: 100.62
# store_class_mean_7_decay: 96.76
# promo_-12: 96.46
# store_class_median_14_2: 91.32
# store_class_mean_60_2: 89.42
# min_30: 89.05
# min_60: 84.88
# promo_-16: 84.59
# store_class_mean_7_2: 83.10
# store_class_mean_7_decay_2: 82.75
# store_class_has_promo_days_in_last_7: 82.55
# item_first_has_sales_day_in_last_30: 81.28
# promo_-5: 78.03
# store_class_median_14: 77.85
# promo_-7: 77.43
# min_60_2: 77.18
# store_class_last_has_promo_day_in_last_30: 76.43
# promo_-13: 75.18
# last_has_sales_day_in_last_140: 74.28
# store_class_median_60: 73.01
# store_class_mean_140: 72.94
# promo_-8: 72.74
# promo_14: 72.71
# store_class_mean_14: 70.68
# store_class_has_sales_days_in_last_60: 65.56
# promo_13: 64.35
# promo_-14: 63.33
# store_class_median_60_2: 56.22
# has_promo_days_in_last_14: 55.64
# min_140_2: 54.87
# store_class_median_30: 53.38
# store_class_mean_14_2: 48.56
# promo_11: 38.86
# store_class_mean_14_decay: 38.24
# store_class_mean_30_decay: 34.60
# item_mean_140_decay_2: 34.48
# store_class_mean_30_2: 32.80
# store_class_mean_30: 31.33
# store_class_mean_30_decay_2: 31.06
# store_class_mean_60: 29.84
# store_class_first_has_sales_day_in_last_60: 25.81
# store_class_has_sales_days_in_last_30: 24.12
# store_class_mean_14_decay_2: 23.21
# store_class_first_has_sales_day_in_last_7: 23.20
# promo_12: 22.25
# promo_-11: 19.01
# store_class_mean_140_decay: 18.61
# promo_10: 17.66
# min_140: 15.91
# store_class_mean_140_decay_2: 12.41
# promo_15: 12.22
# promo_-10: 10.84
# store_class_mean_60_decay_2: 10.02
# store_class_has_sales_days_in_last_14: 9.51
# promo_-3: 6.98
# promo_-9: 4.57
# store_class_mean_60_decay: 4.29
# promo_-4: 0.00
# promo_-1: 0.00
# item_has_sales_days_in_last_7: 0.00
# item_last_has_sales_day_in_last_7: 0.00
# item_first_has_sales_day_in_last_7: 0.00
# item_has_sales_days_in_last_14: 0.00
# item_last_has_sales_day_in_last_14: 0.00
# item_first_has_sales_day_in_last_14: 0.00
# item_last_has_sales_day_in_last_30: 0.00
# item_last_has_sales_day_in_last_60: 0.00
# item_last_has_sales_day_in_last_140: 0.00
# store_class_has_sales_days_in_last_7: 0.00
# store_class_last_has_sales_day_in_last_7: 0.00
# store_class_last_has_sales_day_in_last_14: 0.00
# store_class_first_has_sales_day_in_last_14: 0.00
# store_class_last_has_sales_day_in_last_30: 0.00
# store_class_first_has_sales_day_in_last_30: 0.00
# store_class_last_has_sales_day_in_last_60: 0.00
# store_class_last_has_sales_day_in_last_140: 0.00
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [50]	training's l2: 0.436126	valid_1's l2: 0.458153
# [100]	training's l2: 0.335735	valid_1's l2: 0.357155
# [150]	training's l2: 0.316348	valid_1's l2: 0.338489
# [200]	training's l2: 0.309444	valid_1's l2: 0.333188
# [250]	training's l2: 0.305322	valid_1's l2: 0.330914
# [300]	training's l2: 0.302221	valid_1's l2: 0.329849
# [350]	training's l2: 0.299895	valid_1's l2: 0.329109
# [400]	training's l2: 0.298012	valid_1's l2: 0.328625
# [450]	training's l2: 0.29632	valid_1's l2: 0.328199
# [500]	training's l2: 0.294812	valid_1's l2: 0.327861
# [550]	training's l2: 0.293418	valid_1's l2: 0.32758
# [600]	training's l2: 0.292113	valid_1's l2: 0.327356
# [650]	training's l2: 0.29086	valid_1's l2: 0.327159
# [700]	training's l2: 0.289684	valid_1's l2: 0.327045
# [750]	training's l2: 0.288577	valid_1's l2: 0.32696
# [800]	training's l2: 0.287531	valid_1's l2: 0.326885
# [850]	training's l2: 0.286463	valid_1's l2: 0.326739
# [900]	training's l2: 0.285446	valid_1's l2: 0.326664
# [950]	training's l2: 0.284456	valid_1's l2: 0.326581
# [1000]	training's l2: 0.283502	valid_1's l2: 0.326528
# [1050]	training's l2: 0.2826	valid_1's l2: 0.326494
# [1100]	training's l2: 0.281705	valid_1's l2: 0.3264
# [1150]	training's l2: 0.280807	valid_1's l2: 0.32634
# [1200]	training's l2: 0.279938	valid_1's l2: 0.326328
# [1250]	training's l2: 0.279084	valid_1's l2: 0.3263
# [1300]	training's l2: 0.278234	valid_1's l2: 0.326251
# [1350]	training's l2: 0.277413	valid_1's l2: 0.326233
# [1400]	training's l2: 0.276599	valid_1's l2: 0.326189
# [1450]	training's l2: 0.275787	valid_1's l2: 0.326127
# [1500]	training's l2: 0.275004	valid_1's l2: 0.326073
# [1550]	training's l2: 0.274203	valid_1's l2: 0.326016
# [1600]	training's l2: 0.27342	valid_1's l2: 0.325978
# [1650]	training's l2: 0.272669	valid_1's l2: 0.325947
# [1700]	training's l2: 0.271921	valid_1's l2: 0.325923
# [1750]	training's l2: 0.271167	valid_1's l2: 0.325926
# [1800]	training's l2: 0.270415	valid_1's l2: 0.325913
# [1850]	training's l2: 0.269671	valid_1's l2: 0.325849
# [1900]	training's l2: 0.268942	valid_1's l2: 0.325818
# [1950]	training's l2: 0.268207	valid_1's l2: 0.325827
# [2000]	training's l2: 0.267504	valid_1's l2: 0.325842
# [2050]	training's l2: 0.266798	valid_1's l2: 0.325806
# Early stopping, best iteration is:
# [1927]	training's l2: 0.268548	valid_1's l2: 0.325801
# mean_140_decay: 6212276.74
# mean_60_decay: 4167820.15
# mean_7: 1490057.17
# mean_4_dow2_2017: 746953.29
# mean_20_dow2_2017: 686288.23
# promo_2: 350095.64
# mean_30_decay: 208388.46
# item_promo_2: 110980.45
# median_7: 108962.32
# no_promo_mean_140_decay: 70871.41
# mean_7_decay: 59943.49
# item_diff_30_mean: 52973.49
# mean_14_decay: 43547.18
# median_14: 43045.27
# no_promo_mean_60_decay: 40065.70
# promo_3_2017_aft: 38793.42
# has_promo_mean_140: 36620.12
# no_promo_mean_60: 33218.89
# first_has_promo_day_in_after_15_days: 33006.97
# item_diff_7_mean: 30770.37
# day_5_2017: 29973.43
# has_promo_mean_60: 25307.73
# std_14: 24595.83
# no_promo_mean_30: 22969.73
# no_promo_mean_14_decay: 22185.60
# has_promo_mean_14: 21614.52
# item_diff_14_mean: 21213.20
# max_7: 20500.47
# promo_-5: 19394.14
# no_promo_mean_14: 18873.74
# promo_7_2017_aft: 18792.58
# mean_4_dow1_2017: 18255.46
# no_promo_mean_3_decay: 17768.70
# no_promo_mean_30_decay: 17697.40
# item_day_5_2017: 17213.01
# std_30: 16836.93
# day_12_2017: 15157.58
# no_promo_mean_7_decay: 14665.63
# store_nbr: 14482.27
# has_promo_mean_30: 14459.80
# median_60: 14007.22
# no_promo_mean_140: 14000.00
# std_7: 13799.19
# item_diff_3_mean_2: 13626.19
# item_diff_140_mean: 13489.47
# day_4_2017: 12907.15
# std_140: 12391.04
# no_promo_mean_7: 12376.60
# has_promo_mean_7: 11986.56
# store_class_diff_140_mean_2: 10687.38
# type: 10628.12
# std_60: 10617.52
# diff_7_mean: 10417.72
# first_has_sales_day_in_last_140: 9801.74
# item_diff_60_mean: 9736.21
# mean_20_dow1_2017: 9468.50
# item_diff_30_mean_2: 9412.43
# std_140_2: 9384.18
# diff_14_mean: 8703.56
# std_30_2: 8620.16
# item_diff_7_mean_2: 8546.98
# item_promo_0: 8400.60
# mean_20_dow4_2017: 7897.05
# promo_9: 7475.54
# has_promo_days_in_after_15_days: 7445.47
# std_60_2: 7402.87
# no_promo_mean_3: 7360.50
# std_3: 7279.85
# diff_30_mean: 7232.71
# item_nbr: 7217.10
# std_14_2: 7175.66
# diff_60_mean: 7107.41
# item_std_7: 7036.55
# diff_3_mean: 7001.87
# item_diff_60_mean_2: 6976.88
# store_class_diff_14_mean: 6877.32
# item_diff_140_mean_2: 6843.24
# item_std_14: 6798.00
# item_min_140: 6781.62
# has_sales_days_in_last_140: 6687.74
# item_diff_3_mean: 6564.53
# item_mean_20_dow4_2017: 6426.20
# item_promo_-5: 6293.43
# std_7_2: 6187.80
# class: 6144.17
# item_diff_14_mean_2: 6110.12
# store_class_diff_7_mean_2: 6097.22
# item_day_12_2017: 6011.11
# item_promo_3_2017_aft: 5848.76
# promo_14_2017_aft: 5785.02
# day_13_2017: 5762.06
# item_has_promo_mean_3: 5697.35
# item_std_7_2: 5629.86
# item_no_promo_mean_3: 5526.59
# diff_140_mean: 5513.25
# last_has_sales_day_in_last_7: 5501.68
# item_std_3_2: 5414.66
# store_class_promo_140_2017: 5362.53
# std_3_2: 5358.45
# promo_140_2017: 5343.63
# item_min_140_2: 5300.97
# first_has_sales_day_in_last_30: 5297.10
# mean_3_decay: 5183.29
# item_std_3: 5013.48
# store_class_diff_60_mean: 4990.69
# store_class_diff_7_mean: 4933.69
# family: 4930.51
# diff_140_mean_2: 4913.45
# mean_20_dow5_2017: 4886.92
# item_std_30_2: 4791.87
# store_class_diff_3_mean_2: 4725.12
# max_14: 4688.70
# diff_60_mean_2: 4628.16
# item_promo_7_2017_aft: 4591.31
# diff_14_mean_2: 4591.10
# item_promo_140_2017: 4590.38
# store_class_diff_30_mean_2: 4588.16
# diff_30_mean_2: 4485.45
# item_day_1_2017: 4455.33
# max_140: 4403.83
# item_std_14_2: 4307.56
# mean_4_dow0_2017: 4252.24
# diff_3_mean_2: 4204.78
# item_mean_20_dow5_2017: 4166.00
# item_min_14_2: 4165.30
# max_14_2: 4145.36
# mean_4_dow3_2017: 4087.50
# store_class_diff_140_mean: 4079.94
# cluster: 4076.91
# diff_7_mean_2: 4075.60
# item_has_promo_mean_14: 4035.43
# first_has_sales_day_in_last_14: 4007.93
# item_promo_14_2017_aft: 4001.88
# item_has_promo_mean_7: 3952.33
# store_class_diff_14_mean_2: 3950.15
# store_class_diff_30_mean: 3939.34
# ...
# item_mean_4_dow4_2017: 3744.05
# mean_4_dow4_2017: 3729.05
# mean_20_dow5_2017: 3708.55
# store_class_promo_7: 3698.70
# store_class_has_promo_mean_7: 3690.11
# diff_3_mean_2: 3677.30
# median_140_2: 3649.60
# item_has_promo_mean_30_decay: 3612.82
# max_30: 3604.71
# mean_4_dow5_2017: 3603.86
# max_3: 3593.69
# mean_14_2: 3581.07
# item_no_promo_mean_60: 3538.84
# item_no_promo_mean_14: 3537.24
# mean_4_dow6_2017: 3535.12
# item_day_12_2017: 3512.96
# store_class_promo_14_2017_aft: 3485.86
# item_min_7: 3482.83
# item_has_promo_mean_3: 3454.24
# max_14_2: 3452.63
# item_no_promo_mean_30_decay: 3449.97
# store_class_no_promo_mean_30: 3445.10
# max_14: 3430.43
# item_min_14: 3408.57
# store_class_no_promo_mean_14: 3391.01
# promo_140_2017: 3390.19
# no_promo_mean_3: 3387.66
# item_has_promo_days_in_last_30: 3378.91
# item_no_promo_mean_14_decay: 3378.50
# mean_4_dow1_2017: 3364.69
# day_4_2017: 3342.59
# item_day_6_2017: 3233.06
# store_class_no_promo_mean_30_decay: 3208.73
# mean_14: 3165.89
# median_14_2: 3165.08
# max_30_2: 3145.02
# item_no_promo_mean_140: 3122.84
# has_sales_days_in_last_30: 3111.96
# store_class_has_promo_days_in_last_60: 3082.07
# item_mean_20_dow2_2017: 3078.23
# item_first_has_promo_day_in_after_15_days: 3067.00
# day_13_2017: 3047.11
# store_class_has_sales_days_in_last_140: 3038.66
# first_has_promo_day_in_last_60: 3034.60
# max_60: 3033.56
# store_class_std_3: 2984.08
# mean_20_dow3_2017: 2978.80
# day_6_2017: 2978.54
# store_class_promo_14_2017: 2974.61
# item_has_promo_mean_7_decay: 2954.43
# median_140: 2904.72
# store_class_has_promo_days_in_after_15_days: 2876.27
# item_mean_20_dow3_2017: 2871.29
# store_class_no_promo_mean_140: 2860.69
# day_11_2017: 2846.51
# item_max_60_2: 2840.07
# mean_30_2: 2832.67
# store_class_std_3_2: 2830.83
# store_class_std_7_2: 2826.51
# store_class_promo_0: 2801.33
# item_no_promo_mean_60_decay: 2799.73
# item_day_7_2017: 2794.75
# item_promo_14_2017: 2786.69
# item_min_14_2: 2786.43
# item_day_13_2017: 2777.27
# store_class_no_promo_mean_60_decay: 2763.62
# mean_7_decay_2: 2712.03
# item_max_60: 2655.86
# median_14: 2651.03
# item_promo_9: 2621.86
# store_class_no_promo_mean_14_decay: 2613.06
# max_60_2: 2597.50
# state: 2585.10
# item_median_140: 2559.81
# mean_140: 2541.26
# day_12_2017: 2539.75
# item_day_14_2017: 2538.65
# item_mean_20_dow0_2017: 2529.64
# store_class_promo_13: 2517.59
# store_class_day_15_2017: 2504.21
# mean_140_2: 2500.06
# item_mean_4_dow0_2017: 2499.12
# mean_60_2: 2496.80
# store_class_first_has_promo_day_in_last_140: 2451.87
# day_3_2017: 2434.61
# item_day_11_2017: 2418.24
# item_promo_6: 2405.25
# promo_10: 2392.57
# last_has_promo_day_in_last_7: 2366.69
# mean_30_decay_2: 2359.20
# item_has_promo_mean_14_decay: 2356.09
# item_promo_-7: 2354.03
# item_median_60: 2346.83
# store_class_no_promo_mean_3: 2344.28
# day_9_2017: 2325.88
# item_mean_20_dow1_2017: 2321.07
# store_class_last_has_promo_day_in_after_15_days: 2311.04
# mean_3_decay_2: 2303.82
# item_promo_-5: 2303.33
# item_mean_20_dow6_2017: 2281.82
# item_mean_3_decay: 2281.60
# mean_3: 2274.79
# item_mean_20_dow5_2017: 2272.95
# item_has_promo_mean_60_decay: 2271.57
# item_max_3: 2238.31
# item_max_30_2: 2235.09
# item_mean_4_dow2_2017: 2216.87
# min_7: 2199.88
# item_mean_4_dow3_2017: 2192.12
# store_class_std_14: 2152.75
# mean_14_decay_2: 2135.51
# store_class_has_promo_mean_14: 2125.60
# item_median_140_2: 2097.14
# item_mean_4_dow1_2017: 2094.04
# has_promo_days_in_last_30: 2094.03
# store_class_promo_7_2017_aft: 2075.94
# promo_7_2017_aft: 2069.15
# day_10_2017: 2066.68
# first_has_promo_day_in_last_14: 2061.04
# store_class_std_14_2: 2052.71
# store_class_std_140_2: 2021.49
# max_7_2: 2017.38
# store_class_std_7: 2013.03
# store_class_has_promo_mean_60: 1999.17
# store_class_no_promo_mean_7: 1977.48
# item_day_3_2017: 1971.18
# item_mean_4_dow6_2017: 1953.21
# mean_3_decay: 1951.69
# mean_14_decay: 1926.23
# item_max_30: 1921.89
# item_has_promo_mean_140_decay: 1920.11
# store_class_day_14_2017: 1912.33
# store_class_no_promo_mean_140_decay: 1904.87
# item_promo_-14: 1896.94
# item_max_14_2: 1896.46
# item_median_30_2: 1882.11
# store_class_promo_10: 1879.55
# min_14: 1878.33
# first_has_promo_day_in_last_30: 1877.20
# item_max_14: 1867.98
# mean_7_2: 1864.85
# max_3_2: 1864.23
# item_day_10_2017: 1851.90
# store_class_std_140: 1847.76
# item_mean_30_2: 1847.76
# has_promo_mean_3: 1847.35
# store_class_min_140: 1845.44
# min_30: 1838.24
# item_median_14: 1835.32
# item_day_9_2017: 1832.42
# item_max_7: 1823.95
# store_class_promo_9: 1812.33
# store_class_has_promo_mean_30: 1790.55
# store_class_promo_-15: 1772.31
# item_min_7_2: 1771.59
# item_has_promo_days_in_last_7: 1766.68
# item_median_3_2: 1761.71
# first_has_sales_day_in_last_14: 1720.74
# promo_60_2017: 1716.21
# median_30_2: 1691.72
# store_class_promo_3_2017_aft: 1656.08
# store_class_promo_-13: 1653.77
# item_promo_-9: 1649.93
# item_max_3_2: 1639.46
# has_sales_days_in_last_14: 1617.58
# mean_3_2: 1615.08
# item_promo_-12: 1604.29
# store_class_first_has_promo_day_in_last_60: 1592.60
# item_mean_4_dow5_2017: 1583.43
# store_class_has_promo_mean_60_decay: 1579.80
# item_no_promo_mean_140_decay: 1569.85
# item_median_7: 1555.14
# store_class_no_promo_mean_3_decay: 1540.36
# item_has_promo_mean_3_decay: 1525.93
# store_class_promo_-12: 1523.33
# store_class_std_30_2: 1511.93
# store_class_mean_4_dow0_2017: 1505.69
# item_promo_3_2017_aft: 1504.50
# day_8_2017: 1494.21
# store_class_day_12_2017: 1490.94
# item_first_has_promo_day_in_last_14: 1483.30
# item_day_8_2017: 1462.00
# mean_140_decay_2: 1454.69
# store_class_promo_-5: 1446.23
# item_min_3_2: 1444.54
# has_promo_mean_30_decay: 1432.05
# item_mean_60_2: 1423.12
# item_has_sales_days_in_last_30: 1421.39
# store_class_no_promo_mean_7_decay: 1404.72
# item_mean_140_2: 1381.31
# item_median_14_2: 1379.21
# median_3_2: 1378.12
# promo_15: 1376.87
# store_class_day_2_2017: 1347.68
# store_class_std_60_2: 1327.95
# store_class_has_promo_mean_140: 1316.18
# item_median_30: 1300.83
# store_class_min_30_2: 1289.11
# store_class_promo_8: 1284.17
# store_class_promo_6: 1274.75
# store_class_day_5_2017: 1269.73
# median_7_2: 1258.89
# store_class_min_60: 1254.27
# store_class_promo_-8: 1252.54
# store_class_std_60: 1249.68
# store_class_std_30: 1247.50
# store_class_has_promo_mean_140_decay: 1242.40
# item_promo_-16: 1226.34
# store_class_has_promo_mean_7_decay: 1213.27
# item_max_7_2: 1183.10
# item_promo_-10: 1181.70
# has_promo_mean_140_decay: 1181.46
# store_class_day_1_2017: 1180.48
# store_class_day_7_2017: 1178.69
# store_class_has_promo_days_in_last_30: 1174.16
# item_promo_4: 1164.88
# item_mean_3: 1148.27
# item_first_has_promo_day_in_last_7: 1142.86
# store_class_has_promo_mean_14_decay: 1128.15
# store_class_promo_11: 1123.24
# store_class_min_140_2: 1110.20
# min_3: 1097.71
# store_class_promo_-16: 1095.42
# store_class_has_promo_mean_3_decay: 1084.64
# store_class_min_14_2: 1082.15
# store_class_promo_2: 1082.11
# item_promo_-13: 1059.63
# item_promo_-3: 1051.05
# item_promo_-8: 1047.83
# store_class_day_13_2017: 1045.65
# store_class_promo_12: 1040.59
# mean_60_decay_2: 1039.74
# item_mean_60: 1035.83
# item_median_7_2: 1021.34
# store_class_min_7: 1018.48
# item_mean_14_2: 1011.72
# store_class_day_6_2017: 1009.67
# store_class_promo_-10: 1005.85
# has_promo_mean_14_decay: 1004.57
# store_class_day_11_2017: 999.13
# item_mean_14_decay: 995.89
# item_mean_7: 992.15
# store_class_day_8_2017: 991.95
# store_class_day_9_2017: 981.31
# item_last_has_promo_day_in_last_140: 976.04
# store_class_min_60_2: 975.01
# store_class_promo_-2: 971.29
# store_class_promo_-9: 968.79
# item_promo_2: 960.84
# store_class_min_7_2: 960.36
# store_class_day_4_2017: 946.83
# item_mean_140: 938.25
# has_promo_mean_3_decay: 935.15
# item_promo_-15: 933.45
# promo_-7: 924.15
# store_class_mean_4_dow2_2017: 922.85
# store_class_has_promo_mean_30_decay: 911.15
# store_class_min_30: 905.23
# min_3_2: 901.99
# item_promo_1: 887.28
# item_promo_-11: 877.71
# item_last_has_promo_day_in_last_30: 874.12
# store_class_mean_20_dow0_2017: 866.87
# item_mean_3_decay_2: 840.91
# store_class_first_has_promo_day_in_last_30: 834.25
# store_class_mean_4_dow5_2017: 833.98
# first_has_sales_day_in_last_7: 819.17
# has_promo_mean_60_decay: 810.03
# store_class_promo_-11: 806.47
# item_mean_30_decay: 804.87
# store_class_min_3: 790.27
# last_has_promo_day_in_last_14: 790.12
# has_promo_days_in_last_140: 775.85
# store_class_mean_20_dow3_2017: 774.36
# has_promo_mean_7_decay: 772.14
# store_class_first_has_promo_day_in_last_7: 766.48
# store_class_promo_-1: 761.79
# store_class_promo_1: 756.26
# item_mean_3_2: 747.52
# item_mean_7_decay: 747.22
# item_last_has_promo_day_in_last_7: 741.02
# store_class_day_3_2017: 737.83
# store_class_first_has_promo_day_in_last_14: 730.96
# store_class_promo_-6: 709.82
# store_class_max_140: 708.26
# store_class_mean_20_dow4_2017: 682.36
# item_mean_7_decay_2: 680.72
# store_class_median_3: 676.51
# promo_8: 675.09
# store_class_day_10_2017: 664.20
# store_class_promo_5: 663.82
# store_class_promo_-3: 661.11
# store_class_max_140_2: 653.84
# item_promo_5: 652.16
# store_class_min_14: 651.67
# store_class_mean_4_dow1_2017: 644.95
# store_class_min_3_2: 638.54
# item_mean_7_2: 624.24
# min_7_2: 624.03
# store_class_mean_20_dow2_2017: 621.35
# item_mean_30: 616.67
# store_class_median_140_2: 607.27
# promo_11: 601.87
# last_has_promo_day_in_last_30: 597.30
# min_14_2: 596.24
# store_class_promo_4: 595.05
# item_mean_14_decay_2: 591.20
# item_first_has_sales_day_in_last_30: 589.63
# item_promo_-6: 588.06
# store_class_max_7: 585.02
# item_promo_-1: 583.99
# store_class_mean_20_dow6_2017: 574.63
# store_class_promo_-4: 553.98
# store_class_mean_4_dow4_2017: 553.94
# store_class_mean_20_dow5_2017: 553.45
# store_class_max_30_2: 553.05
# last_has_promo_day_in_last_140: 543.96
# item_mean_14: 534.79
# store_class_promo_3: 521.04
# store_class_mean_4_dow3_2017: 506.23
# store_class_first_has_promo_day_in_after_15_days: 501.80
# store_class_max_3: 497.71
# item_last_has_promo_day_in_last_60: 494.19
# has_sales_days_in_last_7: 487.15
# store_class_mean_20_dow1_2017: 486.11
# store_class_max_14_2: 472.43
# store_class_max_60_2: 466.98
# item_promo_3: 464.62
# store_class_median_3_2: 460.42
# store_class_has_promo_days_in_last_14: 460.11
# item_promo_-4: 458.74
# item_mean_140_decay: 442.32
# store_class_max_7_2: 431.97
# store_class_median_140: 430.77
# store_class_max_60: 429.36
# min_60: 414.98
# store_class_mean_4_dow6_2017: 413.82
# store_class_max_30: 412.82
# item_mean_60_decay: 406.13
# item_first_has_sales_day_in_last_60: 402.81
# has_promo_days_in_last_60: 392.00
# store_class_median_7_2: 388.54
# min_30_2: 386.01
# store_class_max_14: 383.20
# item_mean_30_decay_2: 377.40
# store_class_max_3_2: 375.35
# item_last_has_promo_day_in_last_14: 357.94
# store_class_median_14_2: 350.13
# last_has_promo_day_in_last_60: 349.79
# promo_-8: 334.34
# store_class_mean_3_2: 322.21
# store_class_last_has_promo_day_in_last_140: 318.72
# store_class_median_30_2: 304.53
# promo_14_2017: 303.65
# item_last_has_sales_day_in_last_7: 301.25
# store_class_median_7: 298.88
# store_class_mean_60_2: 281.74
# store_class_mean_3_decay_2: 265.96
# store_class_mean_7_2: 261.43
# promo_-15: 240.05
# store_class_last_has_promo_day_in_last_7: 221.75
# item_mean_60_decay_2: 218.29
# last_has_sales_day_in_last_7: 216.58
# store_class_has_promo_days_in_last_7: 212.25
# store_class_mean_140: 209.27
# store_class_median_60_2: 207.62
# store_class_last_has_promo_day_in_last_60: 207.44
# store_class_mean_3_decay: 206.12
# item_mean_140_decay_2: 187.42
# has_promo_days_in_last_7: 184.95
# store_class_median_60: 180.64
# store_class_mean_14_2: 172.68
# item_first_has_sales_day_in_last_7: 172.36
# item_has_sales_days_in_last_14: 171.15
# store_class_mean_140_2: 170.16
# store_class_median_14: 165.00
# store_class_mean_3: 161.65
# promo_3_2017_aft: 152.21
# store_class_mean_14_decay: 148.97
# store_class_last_has_promo_day_in_last_30: 138.98
# promo_-14: 138.49
# store_class_mean_7: 135.01
# store_class_median_30: 121.89
# store_class_mean_7_decay_2: 117.68
# store_class_mean_7_decay: 115.13
# store_class_mean_14_decay_2: 111.41
# item_last_has_sales_day_in_last_140: 107.89
# store_class_mean_14: 105.94
# store_class_mean_30_2: 105.55
# promo_-5: 102.79
# min_60_2: 101.35
# store_class_mean_60: 95.27
# last_has_sales_day_in_last_14: 94.07
# promo_2: 83.50
# store_class_last_has_promo_day_in_last_14: 82.39
# min_140_2: 76.94
# promo_4: 71.34
# promo_-16: 70.50
# store_class_has_sales_days_in_last_60: 61.77
# min_140: 58.40
# item_last_has_sales_day_in_last_30: 55.08
# store_class_mean_60_decay: 54.27
# store_class_mean_30: 51.53
# promo_6: 47.69
# store_class_mean_30_decay: 46.64
# store_class_mean_140_decay_2: 44.58
# store_class_mean_30_decay_2: 41.56
# promo_-12: 39.87
# last_has_sales_day_in_last_30: 38.79
# store_class_mean_60_decay_2: 37.52
# last_has_sales_day_in_last_60: 35.62
# item_first_has_sales_day_in_last_14: 35.61
# promo_-13: 32.10
# promo_5: 28.54
# promo_-4: 26.48
# promo_-3: 24.02
# item_last_has_sales_day_in_last_14: 23.54
# store_class_has_sales_days_in_last_14: 21.07
# store_class_mean_140_decay: 20.43
# promo_-9: 17.57
# store_class_has_sales_days_in_last_30: 17.52
# promo_-1: 16.55
# promo_-11: 14.46
# has_promo_days_in_last_14: 12.53
# last_has_sales_day_in_last_140: 10.78
# promo_-6: 9.32
# store_class_first_has_sales_day_in_last_14: 6.98
# store_class_first_has_sales_day_in_last_30: 5.55
# store_class_last_has_sales_day_in_last_30: 5.39
# item_has_sales_days_in_last_7: 4.91
# promo_-10: 0.00
# promo_-2: 0.00
# promo_1: 0.00
# promo_3: 0.00
# item_last_has_sales_day_in_last_60: 0.00
# store_class_has_sales_days_in_last_7: 0.00
# store_class_last_has_sales_day_in_last_7: 0.00
# store_class_first_has_sales_day_in_last_7: 0.00
# store_class_last_has_sales_day_in_last_14: 0.00
# store_class_last_has_sales_day_in_last_60: 0.00
# store_class_first_has_sales_day_in_last_60: 0.00
# store_class_last_has_sales_day_in_last_140: 0.00
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 125 rounds.
# [50]	training's l2: 0.452781	valid_1's l2: 0.458347
# [100]	training's l2: 0.36947	valid_1's l2: 0.380155
# [150]	training's l2: 0.351706	valid_1's l2: 0.366205
# [200]	training's l2: 0.344209	valid_1's l2: 0.362
# [250]	training's l2: 0.338901	valid_1's l2: 0.359944
# [300]	training's l2: 0.334922	valid_1's l2: 0.358501
# [350]	training's l2: 0.331863	valid_1's l2: 0.357537
# [400]	training's l2: 0.329223	valid_1's l2: 0.356721
# [450]	training's l2: 0.326961	valid_1's l2: 0.35617
# [500]	training's l2: 0.324984	valid_1's l2: 0.355779
# [550]	training's l2: 0.323166	valid_1's l2: 0.355377
# [600]	training's l2: 0.321457	valid_1's l2: 0.355104
# [650]	training's l2: 0.31987	valid_1's l2: 0.354837
# [700]	training's l2: 0.318407	valid_1's l2: 0.354617
# [750]	training's l2: 0.317008	valid_1's l2: 0.354438
# [800]	training's l2: 0.315684	valid_1's l2: 0.354301
# [850]	training's l2: 0.314448	valid_1's l2: 0.354151
# [900]	training's l2: 0.313227	valid_1's l2: 0.353998
# [950]	training's l2: 0.312073	valid_1's l2: 0.353868
# [1000]	training's l2: 0.310942	valid_1's l2: 0.353757
# [1050]	training's l2: 0.309858	valid_1's l2: 0.353634
# [1100]	training's l2: 0.308742	valid_1's l2: 0.353583
# [1150]	training's l2: 0.307688	valid_1's l2: 0.353547
# [1200]	training's l2: 0.306706	valid_1's l2: 0.353491
# [1250]	training's l2: 0.305733	valid_1's l2: 0.353446
# [1300]	training's l2: 0.304741	valid_1's l2: 0.353369
# [1350]	training's l2: 0.303791	valid_1's l2: 0.353306
# [1400]	training's l2: 0.302812	valid_1's l2: 0.35326
# [1450]	training's l2: 0.301913	valid_1's l2: 0.353214
# [1500]	training's l2: 0.301012	valid_1's l2: 0.353141
# [1550]	training's l2: 0.300112	valid_1's l2: 0.353093
# [1600]	training's l2: 0.299257	valid_1's l2: 0.353071
# [1650]	training's l2: 0.298374	valid_1's l2: 0.353031
# [1700]	training's l2: 0.297517	valid_1's l2: 0.353013
# [1750]	training's l2: 0.296671	valid_1's l2: 0.352997
# [1800]	training's l2: 0.295839	valid_1's l2: 0.352982
# [1850]	training's l2: 0.29504	valid_1's l2: 0.353006
# [1900]	training's l2: 0.294219	valid_1's l2: 0.352977
# [1950]	training's l2: 0.293428	valid_1's l2: 0.352964
# [2000]	training's l2: 0.292663	valid_1's l2: 0.352928
# [2050]	training's l2: 0.291885	valid_1's l2: 0.352867
# [2100]	training's l2: 0.291094	valid_1's l2: 0.352848
# [2150]	training's l2: 0.290325	valid_1's l2: 0.352841
# [2200]	training's l2: 0.289568	valid_1's l2: 0.352846
# [2250]	training's l2: 0.288794	valid_1's l2: 0.352788
# [2300]	training's l2: 0.28806	valid_1's l2: 0.352757
# [2350]	training's l2: 0.287298	valid_1's l2: 0.352743
# [2400]	training's l2: 0.286541	valid_1's l2: 0.35273

# %% [markdown]
# # 4 提交结果

# %%
print("[INFO] Making submission...")

y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(
    y_test, index=df_2017.index, 
    columns=pd.date_range('2017-08-16', periods=16)
).stack().to_frame('unit_sales')
df_preds.index.set_names(['store_nbr', 'item_nbr', 'date'], inplace=True)

# %%
submission = df_test[['id']].join(df_preds, how='left').fillna(0)
submission['unit_sales'] = np.clip(np.expm1(submission['unit_sales']), 0, 1000)
submission.to_csv('lgb_sub.csv', float_format='%.4f', index=None)
